# %%
# %run ../paths.py

# %%
import pandas as pd
from tqdm.auto import tqdm
tqdm.pandas()
# Out:
# /home/sandhya/Project/final/lib/python3.7/site-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
train = pd.read_csv(CONST().TRAIN_DATA)
test = pd.read_csv(CONST().TEST_DATA)

# %%
pd.read_csv(CONST().TRAIN_DATA).tweet[2]
# Out:
# 'RT @NoelleonFOX7: Protestors rally to support teen facing life sentence in pot brownie case http://t.co/TXXnmbpOoA&#8221;wtf smh not for a brownie'

# %%
# %run ../src/processing/glove_utils.py

# %%
glove_embed = load_embed(CONST.GLOVE_100d)

# %%
# %run ../src/processing/cleaning.py

# %%
train["tweet"] = train["tweet"].progress_apply(lambda tweet: clean_text(tweet,embeddings=True,remove_emojis=False,replace_emojis=True,stopword=False))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=42509.0), HTML(value='')))

# %%
test["tweet"] = test["tweet"].progress_apply(lambda tweet: clean_text(tweet,embeddings=True,remove_emojis=False,replace_emojis=True,stopword=False))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=11949.0), HTML(value='')))

# %%
vocab = build_vocab(list(train['tweet'].apply(lambda x:x.split())))
#vocab
oov = check_coverage(vocab,glove_embed)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=42509.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=41249.0), HTML(value='')))
# Found embeddings for 71.22% of vocab
# Found embeddings for  97.50% of all text

# %%
oov
# Out:
# [('bihday', 659),
#  ('prayfororlando', 74),
#  ('allahsoil', 63),
#  ('erience', 55),
#  ('staing', 54),
#  ('impoant', 49),
#  ('simple,', 48),
#  ('brexit', 46),
#  ('staed', 45),
#  ('orlandoshooting', 45),
#  ('inshot', 39),
#  ('spos', 35),
#  ('heabroken', 35),
#  ('ripchristina', 34),
#  ('altwaystoheal', 30),
#  ('udtapunjab', 30),
#  ('melancholymusic', 25),
#  ('ripchristinagrimmie', 24),
#  ('neverump', 24),
#  ('ected', 24),
#  ('summeime', 23),
#  ('altright', 22),
#  ('bouncingbaby', 22),
#  ('ensive', 21),
#  ('unfounately', 20),
#  ('staup', 20),
#  ('suppoing', 20),
#  ('webukhx', 19),
#  ('ectations', 19),
#  ('suppoers', 19),
#  ('wednesdaywisdom', 18),
#  ('heabreaking', 18),
#  ('christinagrimmie', 18),
#  ('bihdaygirl', 17),
#  ('fuher', 17),
#  ('teambts', 17),
#  ('cultureofdevelopment', 17),
#  ('friyay', 16),
#  ('paner', 16),
#  ('blacklivesmatter', 16),
#  ('inwords', 15),
#  ('osed', 15),
#  ('enteainment', 15),
#  ('oppounity', 14),
#  ('toptags', 14),
#  ('aicle', 13),
#  ('muzzie', 13),
#  ('orlandonightclubshooting', 12),
#  ('loveisland', 12),
#  ('quotestags', 12),
#  ('nothe', 11),
#  ('pougal', 11),
#  ('bihdays', 11),
#  ('antonyelchin', 11),
#  ('factsguide', 11),
#  ('notmypresident', 11),
#  ('ceain', 10),
#  ('soed', 10),
#  ('carlpaladino', 10),
#  ('orangeisthenewblack', 10),
#  ('awork', 10),
#  ('thursdaythoughts', 10),
#  ('caoon', 10),
#  ('coldplaywembley', 10),
#  ('votesos', 9),
#  ('livelypics', 9),
#  ('pulsenightclub', 9),
#  ('staer', 9),
#  ('appletstag', 9),
#  ('schwandorfchwandorf', 9),
#  ('lains', 9),
#  ('theresistance', 9),
#  ('prayfoheworld', 9),
#  ('porait', 9),
#  ('worldoceansday', 9),
#  ('aists', 9),
#  ('woulday', 9),
#  ('eriences', 9),
#  ('relationshipgoals', 8),
#  ('uselections', 8),
#  ('polarisation', 8),
#  ('leftright', 8),
#  ('kscrashcorrectors', 8),
#  ('wakeuppeopl', 8),
#  ('ecting', 8),
#  ('pulseshooting', 8),
#  ('vlicobs', 8),
#  ('teamsuperjunior', 8),
#  ('repoer', 8),
#  ('heabreak', 8),
#  ('oppounities', 8),
#  ('disneygatorattack', 8),
#  ('fleek', 8),
#  ('prayersfororlando', 8),
#  ('yelchin', 8),
#  ('regrann', 8),
#  ('suppoer', 7),
#  ('warcraftmovie', 7),
#  ('imwithher', 7),
#  ('newproject', 7),
#  ('flagday', 7),
#  ('rejectedpeanutsspecials', 7),
#  ('joytrain', 7),
#  ('royalascot', 7),
#  ('nohern', 7),
#  ('donthecon', 7),
#  ('dogsoftwitter', 7),
#  ('webcammodel', 7),
#  ('starek', 7),
#  ('lighttherapy', 7),
#  ('giphy', 7),
#  ('orlandounited', 7),
#  ('osing', 7),
#  ('jocox', 7),
#  ('puntohost', 7),
#  ('shopalyssas', 7),
#  ('indiegamedev', 7),
#  ('jeffsessions', 7),
#  ('unfounate', 7),
#  ('jivemap', 7),
#  ('invitedjive', 7),
#  ('raghuramrajan', 7),
#  ('udtapunjableaked', 7),
#  ('overwatch', 7),
#  ('povey', 7),
#  ('newswithed', 7),
#  ('adveising', 7),
#  ('cedm', 6),
#  ('catsoftwitter', 6),
#  ('apament', 6),
#  ('bihdaysway', 6),
#  ('thinkbigsundaywithmarsha', 6),
#  ('tuesdaymotivation', 6),
#  ('suppoive', 6),
#  ('engrus', 6),
#  ('educationfest', 6),
#  ('ofay', 6),
#  ('libey', 6),
#  ('honkie', 6),
#  ('ladykimora', 6),
#  ('miscegenation', 6),
#  ('amarinder', 6),
#  ('vividsydney', 6),
#  ('upsideofflorida', 6),
#  ('poman', 6),
#  ('notwait', 6),
#  ('mindsconsole', 6),
#  ('blicqer', 6),
#  ('hillaryclinton', 6),
#  ('erienced', 6),
#  ('asianladyboy', 6),
#  ('coolestlifehack', 6),
#  ('cochair', 6),
#  ('freemilo', 5),
#  ('squak', 5),
#  ('antiracism', 5),
#  ('propey', 5),
#  ('bingewatching', 5),
#  ('biher', 5),
#  ('trumpism', 5),
#  ('selfporait', 5),
#  ('flcrashcorrectors', 5),
#  ('htgawm', 5),
#  ('ressing', 5),
#  ('vscogood', 5),
#  ('glastofest', 5),
#  ('canadiangp', 5),
#  ('intermarket', 5),
#  ('shopthemint', 5),
#  ('lained', 5),
#  ('myhappyplace', 5),
#  ('youthday', 5),
#  ('mytraining', 5),
#  ('dogsarejoy', 5),
#  ('fouh', 5),
#  ('muzzies', 5),
#  ('wakow', 5),
#  ('lovewins', 5),
#  ('lokiday', 5),
#  ('paners', 5),
#  ('hillarys', 5),
#  ('ramadankareem', 5),
#  ('ceainly', 5),
#  ('thincc', 5),
#  ('crookedhillary', 5),
#  ('conveible', 5),
#  ('stockboy', 5),
#  ('paicipate', 5),
#  ('selfserving', 5),
#  ('blaxican', 5),
#  ('trumptrain', 5),
#  ('whiteprivilege', 5),
#  ('dumptrump', 5),
#  ('jocoxmp', 5),
#  ('officebearers', 5),
#  ('sukhbir', 5),
#  ('comfoable', 5),
#  ('dementeddonny', 5),
#  ('ression', 5),
#  ('writerslife', 5),
#  ('jeepmafia', 4),
#  ('bihdaykazuki', 4),
#  ('gokaldas', 4),
#  ('antiwhite', 4),
#  ('oitnbchat', 4),
#  ('deleteyouraccount', 4),
#  ('aldub', 4),
#  ('kharkivgram', 4),
#  ('suppoed', 4),
#  ('foreverliving', 4),
#  ('bigly', 4),
#  ('eureferendum', 4),
#  ('stephcurrys', 4),
#  ('mebeforeyou', 4),
#  ('tedatibm', 4),
#  ('zionazis', 4),
#  ('policebrutality', 4),
#  ('bigender', 4),
#  ('prayorlando', 4),
#  ('mogage', 4),
#  ('actorslife', 4),
#  ('trumpuniversity', 4),
#  ('ripantonyelchin', 4),
#  ('lopezchiro', 4),
#  ('unchaed', 4),
#  ('unpresidented', 4),
#  ('apaheid', 4),
#  ('laining', 4),
#  ('fianc', 4),
#  ('founate', 4),
#  ('bdayspl', 4),
#  ('vscoturkey', 4),
#  ('thankfulthursday', 4),
#  ('tubbytoons', 4),
#  ('bestfriendsday', 4),
#  ('injuns', 4),
#  ('eriencing', 4),
#  ('notmypres', 4),
#  ('huing', 4),
#  ('whitegenocide', 4),
#  ('wohy', 4),
#  ('orlandostrong', 4),
#  ('malevote', 4),
#  ('drumpf', 4),
#  ('figgity', 4),
#  ('ojmadeinamerica', 4),
#  ('repoers', 4),
#  ('essentialoils', 4),
#  ('berniesanders', 4),
#  ('peckerwood', 4),
#  ('whitesupremacy', 4),
#  ('antiamerican', 4),
#  ('smaccdub', 4),
#  ('likeforlikealways', 4),
#  ('nuascannan', 4),
#  ('lapride', 4),
#  ('mohenjodaro', 4),
#  ('trumpsamerica', 4),
#  ('dreamproject', 4),
#  ('allivesmatter', 4),
#  ('paicularly', 4),
#  ('weareorlando', 4),
#  ('impoance', 4),
#  ('caoons', 4),
#  ('paladinos', 4),
#  ('democraticpay', 4),
#  ('ghettosdriven', 4),
#  ('shmurda', 4),
#  ('futureofwork', 4),
#  ('weddingpay', 4),
#  ('tshis', 4),
#  ('orlandolove', 4),
#  ('pharrellwilliams', 4),
#  ('barbiets', 4),
#  ('antiblackness', 4),
#  ('shofilm', 4),
#  ('orlandohorror', 4),
#  ('irevswe', 4),
#  ('stopracism', 4),
#  ('loveconquershate', 4),
#  ('prayingfororlando', 4),
#  ('inwoo', 3),
#  ('niggerfag', 3),
#  ('growthhacking', 3),
#  ('annaswelshzoo', 3),
#  ('pittiuomo', 3),
#  ('heaache', 3),
#  ('udta', 3),
#  ('jeepnation', 3),
#  ('nbjc', 3),
#  ('scoopwhoopnews', 3),
#  ('unextraordinary', 3),
#  ('trumpworld', 3),
#  ('smaphone', 3),
#  ('audiblechannels', 3),
#  ('nifo', 3),
#  ('polosi', 3),
#  ('kikes', 3),
#  ('healess', 3),
#  ('makeamericagreatagain', 3),
#  ('stopgunviolence', 3),
#  ('teapay', 3),
#  ('socafrenzy', 3),
#  ('bluedress', 3),
#  ('morelove', 3),
#  ('womenempowerment', 3),
#  ('myhea', 3),
#  ('bodycleanse', 3),
#  ('oitnbseason', 3),
#  ('bihay', 3),
#  ('selfloathing', 3),
#  ('keshis', 3),
#  ('wouldictatorial', 3),
#  ('alkalamba', 3),
#  ('couesy', 3),
#  ('whitesupremacist', 3),
#  ('ectation', 3),
#  ('peckerwoods', 3),
#  ('twtly', 3),
#  ('bihdayweekend', 3),
#  ('msqrd', 3),
#  ('kindleunlimited', 3),
#  ('landholding', 3),
#  ('whiggers', 3),
#  ('feelthebern', 3),
#  ('frarou', 3),
#  ('theconjuring', 3),
#  ('nonracist', 3),
#  ('toyspotting', 3),
#  ('pokemonsunmoon', 3),
#  ('signofthetimes', 3),
#  ('cuain', 3),
#  ('bogotadc', 3),
#  ('gayvegas', 3),
#  ('wepretty', 3),
#  ('webad', 3),
#  ('notil', 3),
#  ('annefrank', 3),
#  ('rapflashback', 3),
#  ('eveon', 3),
#  ('musicaltheatre', 3),
#  ('crists', 3),
#  ('bluehand', 3),
#  ('eriment', 3),
#  ('centralintelligence', 3),
#  ('girlsholiday', 3),
#  ('gahbrooks', 3),
#  ('familytrip', 3),
#  ('healthandfitness', 3),
#  ('brokenquotes', 3),
#  ('akrotiri', 3),
#  ('knossos', 3),
#  ('capitalstb', 3),
#  ('apaments', 3),
#  ('loiting', 3),
#  ('boycottdelta', 3),
#  ('homeon', 3),
#  ('hackneywick', 3),
#  ('rebelhea', 3),
#  ('togetherstronger', 3),
#  ('atbat', 3),
#  ('quaer', 3),
#  ('hoosierstate', 3),
#  ('netflixandchill', 3),
#  ('instaselfie', 3),
#  ('gotmelike', 3),
#  ('dadsday', 3),
#  ('sex,', 3),
#  ('age,', 3),
#  ('traphousee', 3),
#  ('bekindtooneanother', 3),
#  ('wohless', 3),
#  ('vscolove', 3),
#  ('instatagslikes', 3),
#  ('aicles', 3),
#  ('switcharoo', 3),
#  ('mohammedali', 3),
#  ('smilemore', 3),
#  ('alicrytrinkets', 3),
#  ('enjoyinglife', 3),
#  ('xboxones', 3),
#  ('waspi', 3),
#  ('yesallwomen', 3),
#  ('starawards', 3),
#  ('extraordinaryladyspeaks', 3),
#  ('iampossible', 3),
#  ('momtips', 3),
#  ('fashionillustration', 3),
#  ('putinspuppet', 3),
#  ('putinschoice', 3),
#  ('jungkookday', 3),
#  ('mummersparade', 3),
#  ('nohampton', 3),
#  ('highlycontested', 3),
#  ('selfharming', 3),
#  ('gettingfitter', 3),
#  ('colbe', 3),
#  ('deadbydaylight', 3),
#  ('oneplus', 3),
#  ('rickastley', 3),
#  ('girlno', 3),
#  ('infofuny', 3),
#  ('voteleave', 3),
#  ('poussey', 3),
#  ('amodu', 3),
#  ('gratata', 3),
#  ('sweethea', 3),
#  ('golinuntern', 3),
#  ('indvszim', 3),
#  ('theduchessofcambridge', 3),
#  ('aldubthweeksary', 3),
#  ('enforcem', 3),
#  ('celebspot', 3),
#  ('sinkthepink', 3),
#  ('kylielipkit', 3),
#  ('kickstaer', 3),
#  ('venusexchange', 3),
#  ('teamshide', 3),
#  ('shideism', 3),
#  ('thewi', 3),
#  ('pofolio', 3),
#  ('patriotwatch', 3),
#  ('floridashooting', 3),
#  ('newbooks', 3),
#  ('eoeparceria', 3),
#  ('two-hump', 3),
#  ('bihdayyourmajesty', 3),
#  ('newadventure', 3),
#  ('craziestpeoples', 3),
#  ('worldginday', 3),
#  ('mcbob', 3),
#  ('snapchater', 3),
#  ('mybihday', 3),
#  ('abasel', 3),
#  ('yezidi', 3),
#  ('queenat', 3),
#  ('fusionmadness', 3),
#  ('masterkeye', 3),
#  ('rondarousey', 3),
#  ('adamsaleh', 3),
#  ('doplants', 3),
#  ('bihdaycake', 3),
#  ('pueorico', 3),
#  ('cursedchild', 3),
#  ('instatraveling', 3),
#  ('staups', 3),
#  ('bihdayboy', 3),
#  ('summerfair', 3),
#  ('blackheathstandard', 3),
#  ('dragoneducation', 3),
#  ('engwal', 3),
#  ('totellthetruth', 3),
#  ('augustth', 3),
#  ('streeta', 3),
#  ('bobross', 3),
#  ('downloadfestival', 3),
#  ('wouldon', 3),
#  ('zootopia', 3),
#  ('bluelivesmatter', 3),
#  ('nintendoe', 3),
#  ('sundayvibes', 3),
#  ('makeuplover', 3),
#  ('followusoninstagram', 3),
#  ('stylehausboutique', 3),
#  ('albea', 3),
#  ('anglosaxon', 3),
#  ('lgbtqhatestrumppay', 3),
#  ('spoy', 3),
#  ('pueobanus', 3),
#  ('fatherday', 3),
#  ('europeangp', 3),
#  ('katiequeue', 3),
#  ('alltypespos', 3),
#  ('islamicinfo', 3),
#  ('gamesofthrones', 3),
#  ('curbyourenthusiasm', 3),
#  ('dowhatyoulove', 3),
#  ('bookstagram', 3),
#  ('paicular', 3),
#  ('refugeeswelcome', 3),
#  ('alohafriday', 3),
#  ('menner', 3),
#  ('harambe', 3),
#  ('copaamerica', 3),
#  ('lnicjustanevilbday', 3),
#  ('lnic', 3),
#  ('ahfodtour', 3),
#  ('fotokuapp', 3),
#  ('maialas', 3),
#  ('microaggressions', 3),
#  ('blogtacular', 3),
#  ('oscarpretorious', 3),
#  ('freshsta', 3),
#  ('drugaddicts', 3),
#  ('kimorablac', 3),
#  ('yrkkh', 3),
#  ('draintheswamp', 3),
#  ('nattaway', 2),
#  ('kadesh', 2),
#  ('usatt', 2),
#  ('unreformable', 2),
#  ('melges', 2),
#  ('foitude', 2),
#  ('ethnocentrism', 2),
#  ('doublesided', 2),
#  ('naoyuki', 2),
#  ('newplace', 2),
#  ('qcbags', 2),
#  ('hickstead', 2),
#  ('ilovegin', 2),
#  ('chaani', 2),
#  ('zionazi', 2),
#  ('girlboss', 2),
#  ('choling', 2),
#  ('cinemahall', 2),
#  ('thweeksary', 2),
#  ('bihdayjodistamaria', 2),
#  ('ngitingtagumpay', 2),
#  ('blessedandthankful', 2),
#  ('thegrapegirls', 2),
#  ('nationalroseday', 2),
#  ('chatbot', 2),
#  ('yahoomessenger', 2),
#  ('senseaboutmaths', 2),
#  ('adahzeh', 2),
#  ('therealflatfoot', 2),
#  ('biserjamess', 2),
#  ('buckinghampalace', 2),
#  ('aneveningwithcyrus', 2),
#  ('teletubbiesusa', 2),
#  ('ontheredcarpet', 2),
#  ('argvbol', 2),
#  ('justicereform', 2),
#  ('nrocks', 2),
#  ('voez', 2),
#  ('sitgesanytime', 2),
#  ('envatomarket', 2),
#  ('bihdaycelebrations', 2),
#  ('birstall', 2),
#  ('milleniawalk', 2),
#  ('skyback', 2),
#  ('oculusrift', 2),
#  ('summershowers', 2),
#  ('findhappiness', 2),
#  ('enteain', 2),
#  ('almostweekend', 2),
#  ('hepwoh', 2),
#  ('amaniknew', 2),
#  ('paxex', 2),
#  ('unitednations', 2),
#  ('fuckguns', 2),
#  ('houseofolive', 2),
#  ('rajkuamar', 2),
#  ('bodyscrubs', 2),
#  ('scrab', 2),
#  ('communalise', 2),
#  ('wheredobrokenheasgo', 2),
#  ('wheredoibelong', 2),
#  ('womenvote', 2),
#  ('abrahamhicks', 2),
#  ('heatherfitzpatrick', 2),
#  ('bestpeople', 2),
#  ('thankyoustudio', 2),
#  ('goreing', 2),
#  ('sunworld', 2),
#  ('lstv', 2),
#  ('toomanyemorions', 2),
#  ('didthatreallyjusthappen', 2),
#  ('readytopay', 2),
#  ('bihdaytreat', 2),
#  ('datemyfamily', 2),
#  ('squadgoals', 2),
#  ('greatacting', 2),
#  ('emptynest', 2),
#  ('coolwallet', 2),
#  ('lutsen', 2),
#  ('fridayfunday', 2),
#  ('businessoppounity', 2),
#  ('itwing', 2),
#  ('greendays', 2),
#  ('mckechnie', 2),
#  ('socialhistory', 2),
#  ('noheast', 2),
#  ('sffs', 2),
#  ('disseation', 2),
#  ('nationalfreelancersday', 2),
#  ('beyourownboss', 2),
#  ('dogfriends', 2),
#  ('jeepgirl', 2),
#  ('cssday', 2),
#  ('nuure', 2),
#  ('votetrumpsave', 2),
#  ('yogalife', 2),
#  ('theodyssey', 2),
#  ('magnettherapy', 2),
#  ('memoriesmatter', 2),
#  ('simonstone', 2),
#  ('desdelaraiz', 2),
#  ('castingcall', 2),
#  ('pileupriddim', 2),
#  ('jewelmaze', 2),
#  ('louismainjr', 2),
#  ('ripanton', 2),
#  ('fisherprice', 2),
#  ('swanlake', 2),
#  ('lanation', 2),
#  ('fireflymusicfestival', 2),
#  ('soundtrainingnews', 2),
#  ('hindalco', 2),
#  ('panono', 2),
#  ('positivevibesonly', 2),
#  ('noheels', 2),
#  ('babylife', 2),
#  ('bragadayjah', 2),
#  ('ahntrio', 2),
#  ('thoughtswithorlando', 2),
#  ('grimmies', 2),
#  ('teamcatmojo', 2),
#  ('sugardaddies', 2),
#  ('ccblooms', 2),
#  ('brewpix', 2),
#  ('laurasworld', 2),
#  ('iamchoosinglove', 2),
#  ('realbeauty', 2),
#  ('junesuitejune', 2),
#  ('stinkyclothes', 2),
#  ('shoking', 2),
#  ('weakdonald', 2),
#  ('spssv', 2),
#  ('spfx', 2),
#  ('adidasler', 2),
#  ('alwaystrump', 2),
#  ('youmakemesmile', 2),
#  ('gdegblog', 2),
#  ('diepsloot', 2),
#  ('animaladvocate', 2),
#  ('authenticself', 2),
#  ('nohcarolina', 2),
#  ('greatsinger', 2),
#  ('bekindtoanimals', 2),
#  ('bekindalways', 2),
#  ('rexit', 2),
#  ('shopes', 2),
#  ('mealprep', 2),
#  ('bobovr', 2),
#  ('beautifulworld', 2),
#  ('selfrealization', 2),
#  ('gmschurch', 2),
#  ('lowenergy', 2),
#  ('spinellis', 2),
#  ('tminushours', 2),
#  ('xians', 2),
#  ('jaguarfpace', 2),
#  ('jaguarstb', 2),
#  ('fpace', 2),
#  ('istillbelievethough', 2),
#  ('findoutnow', 2),
#  ('lovecornwall', 2),
#  ('ponsanooth', 2),
#  ('wsib', 2),
#  ('antisemtism', 2),
#  ('studyni', 2),
#  ('ihbelfast', 2),
#  ('sitgesgaypride', 2),
#  ('thoughtleaders', 2),
#  ('weinerdog', 2),
#  ('angloamerican', 2),
#  ('itaxnirahisi', 2),
#  ('yeezyboost', 2),
#  ('instahappyday', 2),
#  ('hhmatters', 2),
#  ('lainable', 2),
#  ('pulsefitness', 2),
#  ('illrun', 2),
#  ('traumaticbraininjury', 2),
#  ('unasolagozadera', 2),
#  ('thestoneroses', 2),
#  ('growthwithhubspot', 2),
#  ('holymonth', 2),
#  ('goauche', 2),
#  ('eriaz', 2),
#  ('postapocalyptic', 2),
#  ('humpdaymotivation', 2),
#  ('stillwithher', 2),
#  ('notbetterweather', 2),
#  ('selfinterest', 2),
#  ('homehouse', 2),
#  ('kindledeals', 2),
#  ('aldubthmonthsary', 2),
#  ('balless', 2),
#  ('downloadvirgin', 2),
#  ('sheprollygonnadocrack', 2),
#  ('bjmuzic', 2),
#  ('bjmckenzie', 2),
#  ('reignofkong', 2),
#  ('moodoftheday', 2),
#  ('bernieorbust', 2),
#  ('gooddyeyoung', 2),
#  ('syrianrefugees', 2),
#  ('rationchallenge', 2),
#  ('upcm', 2),
#  ('lesshate', 2),
#  ('guncrime', 2),
#  ('myphotography', 2),
#  ('spiritualjourney', 2),
#  ('ripjulimuffn', 2),
#  ('oldpainting', 2),
#  ('jenniferaniston', 2),
#  ('smilepowerday', 2),
#  ('bremain', 2),
#  ('doodlerindelhi', 2),
#  ('shoage', 2),
#  ('nofail', 2),
#  ('bhagmojobhag', 2),
#  ('owlashop', 2),
#  ('emtec', 2),
#  ('traitorump', 2),
#  ('adveise', 2),
#  ('carryhappiness', 2),
#  ('hellolulu', 2),
#  ('mufg', 2),
#  ('junaricrm', 2),
#  ('wcvbpoli', 2),
#  ('uyanze', 2),
#  ('luube', 2),
#  ('gettingreal', 2),
#  ('udtapunjabtoflytomorrow', 2),
#  ('chimpo', 2),
#  ('lowiq', 2),
#  ('queenelizabeths', 2),
#  ('ladylouisewindsor', 2),
#  ('invisibleillness', 2),
#  ('tuckercarlson', 2),
#  ('mumlife', 2),
#  ('poccets', 2),
#  ('ihearadio', 2),
#  ('gplay', 2),
#  ('volunteersweek', 2),
#  ('bmottphoto', 2),
#  ('womenofsteel', 2),
#  ('yogalove', 2),
#  ('lifetips', 2),
#  ('resso', 2),
#  ('flyswiss', 2),
#  ('aftenro', 2),
#  ('popularvote', 2),
#  ('newflat', 2),
#  ('elixer', 2),
#  ('doughdiscoday', 2),
#  ('teamhawthorn', 2),
#  ('radiolife', 2),
#  ('hillbots', 2),
#  ('preprogrammed', 2),
#  ('joepalacios', 2),
#  ('friendshipneverends', 2),
#  ('felizdiadelpadre', 2),
#  ('yosoytupadre', 2),
#  ('hogwas', 2),
#  ('weddingtime', 2),
#  ('bynight', 2),
#  ('openwaterswimming', 2),
#  ('climatecrimes', 2),
#  ('antiracist', 2),
#  ('kongebloggen', 2),
#  ('comicpalooza', 2),
#  ('hereticfoundation', 2),
#  ('powerhungrytraitors', 2),
#  ('parsonsxteenvogue', 2),
#  ('troopingthecolour', 2),
#  ('sosassy', 2),
#  ('funnymemes', 2),
#  ('galwayhour', 2),
#  ('barryjayhughes', 2),
#  ('ceificate', 2),
#  ('ladyzaradurose', 2),
#  ('jadhav', 2),
#  ('inktober', 2),
#  ('damoor', 2),
#  ('bravebu', 2),
#  ('mrssa', 2),
#  ('twtl', 2),
#  ('subgenres', 2),
#  ('studentnurse', 2),
#  ('denzy', 2),
#  ('weenis', 2),
#  ('pmpm', 2),
#  ('besteduonline', 2),
#  ('whitenationalist', 2),
#  ('descendantsofthesun', 2),
#  ('howbeautifultour', 2),
#  ('ottawaigers', 2),
#  ('summerisbetter', 2),
#  ('jonsnow', 2),
#  ('excitem', 2),
#  ('farewellrexallplace', 2),
#  ('summerk', 2),
#  ('amjoy', 2),
#  ('vdawg', 2),
#  ('theyorkshirespirit', 2),
#  ('danieldash', 2),
#  ('dominicanblogger', 2),
#  ('usedbytrump', 2),
#  ('antaica', 2),
#  ('gorgeousgirl', 2),
#  ('tinfoilhat', 2),
#  ('sequinbow', 2),
#  ('thinskinned', 2),
#  ('ludacriss', 2),
#  ('verbalassault', 2),
#  ('goodvibesonly', 2),
#  ('hulkmode', 2),
#  ('lukehemmings', 2),
#  ('livelifetothefullest', 2),
#  ('prechula', 2),
#  ('miniwd', 2),
#  ('tehaleh', 2),
#  ('holmium', 2),
#  ('vsupercars', 2),
#  ('amensia', 2),
#  ('crashbandicoot', 2),
#  ('stockphoto', 2),
#  ('helthy', 2),
#  ('liveinthemoment', 2),
#  ('quaerly', 2),
#  ('curriculumday', 2),
#  ('scrumy', 2),
#  ('dailysketch', 2),
#  ('jarretts', 2),
#  ('followanyway', 2),
#  ('islamicterrorism', 2),
#  ('happycampers', 2),
#  ('socialanxiety', 2),
#  ('narnfraud', 2),
#  ('magnetize', 2),
#  ('parkhouse', 2),
#  ('cloudlovers', 2),
#  ('heroesdayug', 2),
#  ('firsthome', 2),
#  ('waterspos', 2),
#  ('fathersdaymessage', 2),
#  ('farright', 2),
#  ('campadams', 2),
#  ('nothese', 2),
#  ('kazzeymusic', 2),
#  ('dinavalenz', 2),
#  ('bihdaypresent', 2),
#  ('biggestever', 2),
#  ('tanamsendiri', 2),
#  ('harummanis', 2),
#  ('wahabism', 2),
#  ('cloudchaser', 2),
#  ('senselessviolence', 2),
#  ('scesdshines', 2),
#  ('rickity', 2),
#  ('liveandletlive', 2),
#  ('colourmehappy', 2),
#  ('letstalkabout', 2),
#  ('heaed', 2),
#  ('wankpuffins', 2),
#  ('cuailing', 2),
#  ('beautifulcityhostel', 2),
#  ('economicapahied', 2),
#  ('notpencil', 2),
#  ('winsorandnewton', 2),
#  ('fabercastell', 2),
#  ('canievenpaintanymore', 2),
#  ('baender', 2),
#  ('toddington', 2),
#  ('sunseasand', 2),
#  ('charmars', 2),
#  ('areverse', 2),
#  ('ineedtoconsult', 2),
#  ('mozlondon', 2),
#  ('canaryislands', 2),
#  ('pahlajnihalani', 2),
#  ('beloy', 2),
#  ('themorningfix', 2),
#  ('bronem', 2),
#  ('pohcawlbikehire', 2),
#  ('blogginggals', 2),
#  ('wodeh', 2),
#  ('indignenous', 2),
#  ('cushite', 2),
#  ('richardspencer', 2),
#  ('insidethebelljar', 2),
#  ('engvrus', 2),
#  ('riskoff', 2),
#  ('jimrohn', 2),
#  ('haggerstoncastlewiththefam', 2),
#  ('twoshot', 2),
#  ('herballife', 2),
#  ('plantbased', 2),
#  ('tokifuji', 2),
#  ('thedayproject', 2),
#  ('lulybtips', 2),
#  ('spreadhappiness', 2),
#  ('stephenkeshi', 2),
#  ('anmolshare', 2),
#  ('armaanamaalontkss', 2),
#  ('checkoutmyflyer', 2),
#  ('donttrusthim', 2),
#  ('nottrusthim', 2),
#  ('lovebts', 2),
#  ('techjunkiejh', 2),
#  ('effos', 2),
#  ('thiy', 2),
#  ('americafirst', 2),
#  ('selfdevelopment', 2),
#  ('affirmativeaction', 2),
#  ('newadventures', 2),
#  ('singlemother', 2),
#  ('supposmallstreams', 2),
#  ('naturelovers', 2),
#  ('yuge', 2),
#  ('mysistersgraduation', 2),
#  ('macgrad', 2),
#  ('someonecomewithme', 2),
#  ('samanthabee', 2),
#  ('hohum', 2),
#  ('hotvideo', 2),
#  ('bankerhits', 2),
#  ('unceain', 2),
#  ('ressions', 2),
#  ('upliftingnews', 2),
#  ('hfhradio', 2),
#  ('yehtut', 2),
#  ('goromania', 2),
#  ('brokenhea', 2),
#  ('conflates', 2),
#  ('trumplies', 2),
#  ('appleta', 2),
#  ('mansoon', 2),
#  ('steaknight', 2),
#  ('dadanddaughter', 2),
#  ('goaded', 2),
#  ('egsmile', 2),
#  ('runvi', 2),
#  ('urbacity', 2),
#  ('corroborated', 2),
#  ('lifestyleblogger', 2),
#  ('ubie', 2),
#  ('bringabankstatementandwecantalk', 2),
#  ('canihelpyou', 2),
#  ('everydaybeautiful', 2),
#  ('toureiffel', 2),
#  ('sexualpredator', 2),
#  ('keepu', 2),
#  ('timhoons', 2),
#  ('bearlovestravel', 2),
#  ('riclswtravelbook', 2),
#  ('reathie', 2),
#  ('helloe', 2),
#  ('behello', 2),
#  ('lovereading', 2),
#  ('systemicracism', 2),
#  ('stoni', 2),
#  ('woodrowwilson', 2),
#  ('jesuslovesyou', 2),
#  ('glastonburyfestival', 2),
#  ('fowoh', 2),
#  ('trumpusa', 2),
#  ('mateens', 2),
#  ('australiangold', 2),
#  ('blacksea', 2),
#  ('paulgeorge', 2),
#  ('onebigfamily', 2),
#  ('bloggersblast', 2),
#  ('fahersday', 2),
#  ('eahquake', 2),
#  ('germay', 2),
#  ('salonaks', 2),
#  ('dumbdonalddestroying', 2),
#  ('ivankatrump', 2),
#  ('takuyakimura', 2),
#  ('waitingf', 2),
#  ('nodream', 2),
#  ('boringlives', 2),
#  ('globalwellnessday', 2),
#  ('bankett', 2),
#  ('enteaining', 2),
#  ('vintagestyle', 2),
#  ('illmissyouguys', 2),
#  ('gratefuleveryday', 2),
#  ('ilitary', 2),
#  ('watchm', 2),
#  ('weekendfun', 2),
#  ('cricker', 2),
#  ('weddingcountdown', 2),
#  ('traveltheworld', 2),
#  ('kushite', 2),
#  ('ysrah', 2),
#  ('ohodontic', 2),
#  ('whererefreshingbegins', 2),
#  ('ckkosho', 2),
#  ('dadsrock', 2),
#  ('growthmindset', 2),
#  ('casfactor', 2),
#  ('tosoon', 2),
#  ('dailycatimpression', 2),
#  ('frankfu', 2),
#  ...]

# %%
spellings = dict()

for tup in oov[:350]:
    word = tup[0]
    correct = spell_checker(word)
    spellings[word] = correct

# %%
spellings = {'bihday': 'birthday',
 'staing': 'staying',
 'impoant': 'important',
 'staed': 'stayed',
 'erience': 'evidence',
 'unfounately': 'unfortunately',
 'ected': 'acted',
 'suppoers': 'supporters',
 'suppoing': 'supposing',
 'fuher': 'fuhrer',
'fleek':"extremely good",
 'ectations': 'stations',
 'ensive': 'pensive',
 'muzzie': 'muzzle',
 'oppounity': 'opportunity',
 'factsguide': 'facts guide',
 'heabreaking': 'heartbreaking',
 'woulday': 'would',
 'bihdays': 'birthdays',
 'polarisation': 'polarisation',
 'wakeuppeopl': 'wake up people',
 'summeime': 'summer time',
 'heabroken': 'heart broken',
 'staer': 'star',
 'oppounities': 'opportunities',
 'suppoer': 'supporter',
 'nohern': 'modern',
 'quotestags': 'quotes tags',
 'caoon': 'canon',
 'ofay': 'okay',
 'libey': 'libel',
 'notwait': 'not wait',
 'regrann': 'regain',
 'ecting': 'acting',
 'enteainment': 'entrainment',
 'erienced': 'oriented',
 'coolestlifehack': 'coolestlifehack',
 'poman': 'woman',
 'mindsconsole': 'minds console',
 'impoance': 'importance',
 'mytraining': 'training',
 'muzzies': 'muzzles',
 'ceainly': 'certainly',
 'blaxican': 'blaxican',
 'apament': 'apartment',
 'thincc': 'think',
 'fouh': 'four',
 'paicipate': 'participate',
 'suppoive': 'supportive',
 'barbiets': 'barbies',
 'paicularly': 'particularly',
 'heabreak': 'heart break',
 'peckerwood': 'pecker wood',
 'figgity': 'dignity',
 'unfounate': 'unfortunate',
 'eriencing': 'orienting',
 'conveible': 'convertible',
 'friyay': 'friday',
 'repoers': 'report',
 'hillarys': 'hillary',
 'adveising': 'advising',
 'awork': 'work',
 'niggerfag': 'nigger fag',
 'landholding': 'land holding',
 'crists': 'crisis',
 'quaer': 'queer',
 'traphousee': 'trap house',
 'wouldon': 'would',
 'overwatch': 'overwatch',
 'wohy': 'why',
 'intermarket': 'after market',
 'dragoneducation': 'dragon education',
 'paicular': 'particular',
 'notil': 'not',
 'sweethea': 'sweetpea',
 'bihdayyourmajesty': 'birthday your majesty',
 'apaments': 'apartments',
 'cuain': 'chain',
 'nbjc': 'nbc',
 'pofolio': 'portfolio',
 'fusionmadness': 'fusion madness',
 'scoopwhoopnews': 'scoopwhoop news',
 'comfoable': 'comfortable',
 'craziestpeoples': 'craziest people',
 'founate': 'fortunate',
 'unextraordinary': 'not extraordinary',
 'adveised': 'advised',
 'chrishon': 'christen',
 'ckkosho': 'ckkosho',
 'goldmanworld': 'goldman world',
 'excerpted': 'excepted',
 'mufg': 'mug',
 'couuch': 'couch',
 'womenmalayalam': 'women malayalam',
 'grimmies': 'grimes',
 'wohless': 'worthless',
 'depaures': 'departures',
 'sheboutit': 'she about it',
 'checkoutmyflyer': 'check out my flyer',
 'therealflatfoot': 'the real flat foot',
 'bronem': 'broken',
 'slutin': 'solution',
 'excitem': 'excited',
 'toures': 'tours',
 'adveise': 'advise',
 'words>': 'words',
 'heaache': 'headache',
 'aicles': 'artices',
 'euphorix': 'euphoria',
 'biher': 'bihar',
 'depament': 'department',
 'wearetech': 'we are tech',
 'impoantly': 'importantly',
 'poccets': 'pockets',
 'vdawg': 'dawg',
 'weenis': 'weenie',
 'choling': 'cooling',
 'paicipating': 'participating',
 'animaladvocate': 'animal advocate',
 'ressions': 'sessions',
 'techjunkiejh': 'tech junkie',
 'viual': 'vital',
 'bihdayy': 'birthday',
 'ceified': 'certified',
 '<<when': 'when',
 'eveon': 'even',
 'whiggers': 'whingers',
 'nightclubber': 'night clubber',
 'wouldodo': 'would do',
 'dadsday': 'daddy',
 'ceification': 'certification',
 'coolwallet': 'cool wallet',
 'fathersdaymessage': 'fathers day message',
 'heaed': 'headed',
 'depaure': 'departure',
 'internations': 'international',
 'communalise': 'communalism',
 '>rt': 'rt',
 'notoday': 'not today',
 'shopes': 'shops',
 'scrumy': 'scrum',
 'fridayeveryone': 'friday everyone',
 'denzy': 'deny',
 'keepu': 'keep',
 'areverse': 'are verse',
 'ysrah': 'yeah',
 'gplay': 'game play',
 'effos': 'effort',
 'inseion': 'insertion',
 'nottrusthim': 'not trust him',
 'enteain': 'entertain',
 'nighha': 'nigga',
 'yyeellooww': 'yellow',
 'unfilling': 'unwilling',
 'vocies': 'voices',
 'uglist': 'ugliest',
 'totlly': 'totally',
 'mickeytofficial': 'mickey to fficial',
 'coomicon': 'comic con',
 'toinight': 'tonight',
 'dhabas': 'dramas',
 'momsbelike': 'moms be like',
 'nicesunnyblondy': 'nice sunny blondy',
'offppensive':'offensive',
             'excitedent':'excitement',
             'aicle':'article',
            'coolestlifehack':"coolest life hack",
            "blacklivesmatter":"black lives matter",
            "wednesdaywisdom":"wednesday wisdom",
             "thursdaythoughts":"thursday thoughts",
             "theresistance":"the resistance",
             "relationshipgoals":"relationship goals",
             "tuesdaymotivation":"tuesday motivation",
             "protacting":"protecting",
             "bingewatching":"binge watching",
             "myhappyplace":"my happy place",
             "dogsarejoy":"dogs are joy",
             "asianladyboy":"asian lady boy",
             "educationfest":"education fest",
             "respacted":"respected",
             "whiteprivilege":"white privilege",
             "antiracism":"anti racism",
             "deleteyouraccount":"delete your account",
             "foreverliving":"forever living",
             "mebeforeyou":"me before you",
             'policebrutality':"police brutality",
             "thankfulthursday":"thankful thursday",
             "whitegenocide":"white genocide",
             "whitesupremacy":"white supremacy",
             "allivesmatter":"all lives matter",
             "stopracism":"stop racism",
             "women empowerment":"women empowerment",
             "whitesupremacist":"white supremacist",
             "togetherstronger":"together stronger",
             "netflixandchill":"netflix and chill",
             "extraordinaryladyspeaks":"extraordinary lady speaks",
             "selfharming":"self harming",
             "fatherday":"father day",
             "dowhatyoulove":"do what you love",
             "antiwhite":"anti white",
             "fuckguns":"fuck guns",
             "polarisation":"polarization",
             "inwords":"in words",
             "affacted":"affected",
             "notmypresident":"not my president",
             "imwithher":"i am with her",
             "malevote":"male vote",
             "antiblackness":"anti blackness",
             "loveconquershate":"love conquers hate",
             "centralintelligence":"central intelligence",
             "yesallwomen":"yes all women",
             "deadbydaylight":"dead by day light",
             "disrespacting":"disrespecting",
             "refugeeswelcome":"refugees welcome",
             "microaggsessions":"micro aggressions",
             "girlboss":"girl boss",
             "thegrapegirls":"the grape girls",
             "blessedandthankful":"blessed and thankful",
             "istillbelievethough":"i still believe though",
             "antisemtism":"anti  semitism",
             "downloadvirgin":"download virgin",
             "guncrime":"gun crime",
             "lesshate":"less hate",
             "womenofsteel":"women of steel",
             "funnymemes":"funny memes",
             "liveandletlive":"live and let live",
             "donttrusthim":"dont trust him",
             "sexualpredator":"sexual predator",
             "systemicracism":"systemic racism",
             "jesuslovesyou":"jesus loves you",
             "boringlives":"boring lives"
             
             
            
            }

# %%
vocab = build_vocab(list(train['tweet'].apply(lambda x:x.split())))
#vocab
oov = check_coverage(vocab,glove_embed)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=42509.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=41060.0), HTML(value='')))
# Found embeddings for 71.56% of vocab
# Found embeddings for  97.79% of all text

# %%
oov
# Out:
# [('prayfororlando', 74),
#  ('allahsoil', 63),
#  ('simple,', 48),
#  ('brexit', 46),
#  ('orlandoshooting', 45),
#  ('inshot', 39),
#  ('spos', 35),
#  ('ripchristina', 34),
#  ('altwaystoheal', 30),
#  ('udtapunjab', 30),
#  ('melancholymusic', 25),
#  ('ripchristinagrimmie', 24),
#  ('neverump', 24),
#  ('altright', 22),
#  ('bouncingbaby', 22),
#  ('offpensive', 21),
#  ('staup', 20),
#  ('webukhx', 19),
#  ('christinagrimmie', 18),
#  ('teambts', 17),
#  ('cultureofdevelopment', 17),
#  ('paner', 16),
#  ('osed', 15),
#  ('toptags', 14),
#  ('orlandonightclubshooting', 12),
#  ('loveisland', 12),
#  ('nothe', 11),
#  ('pougal', 11),
#  ('antonyelchin', 11),
#  ('ceain', 10),
#  ('soed', 10),
#  ('carlpaladino', 10),
#  ('orangeisthenewblack', 10),
#  ('coldplaywembley', 10),
#  ('rejacted', 9),
#  ('votesos', 9),
#  ('livelypics', 9),
#  ('elacted', 9),
#  ('pulsenightclub', 9),
#  ('appletstag', 9),
#  ('schwandorfchwandorf', 9),
#  ('lains', 9),
#  ('prayfoheworld', 9),
#  ('connacting', 9),
#  ('porait', 9),
#  ('worldoceansday', 9),
#  ('aists', 9),
#  ('uselections', 8),
#  ('leftright', 8),
#  ('kscrashcorrectors', 8),
#  ('pulseshooting', 8),
#  ('vlicobs', 8),
#  ('teamsuperjunior', 8),
#  ('repoer', 8),
#  ('disneygatorattack', 8),
#  ('prayersfororlando', 8),
#  ('yelchin', 8),
#  ('connacted', 8),
#  ('warcraftmovie', 7),
#  ('newproject', 7),
#  ('flagday', 7),
#  ('rejactedpeanutsspecials', 7),
#  ('joytrain', 7),
#  ('royalascot', 7),
#  ('donthecon', 7),
#  ('dogsoftwitter', 7),
#  ('webcammodel', 7),
#  ('starek', 7),
#  ('lighttherapy', 7),
#  ('giphy', 7),
#  ('orlandounited', 7),
#  ('osing', 7),
#  ('jocox', 7),
#  ('puntohost', 7),
#  ('shopalyssas', 7),
#  ('indiegamedev', 7),
#  ('jeffsessions', 7),
#  ('jivemap', 7),
#  ('invitedjive', 7),
#  ('raghuramrajan', 7),
#  ('udtapunjableaked', 7),
#  ('overwatch', 7),
#  ('povey', 7),
#  ('newswithed', 7),
#  ('cedm', 6),
#  ('catsoftwitter', 6),
#  ('birthdaysway', 6),
#  ('thinkbigsundaywithmarsha', 6),
#  ('protacted', 6),
#  ('engrus', 6),
#  ('honkie', 6),
#  ('ladykimora', 6),
#  ('miscegenation', 6),
#  ('amarinder', 6),
#  ('vividsydney', 6),
#  ('upsideofflorida', 6),
#  ('blicqer', 6),
#  ('hillaryclinton', 6),
#  ('suspacted', 6),
#  ('cochair', 6),
#  ('freemilo', 5),
#  ('squak', 5),
#  ('propey', 5),
#  ('trumpism', 5),
#  ('selfporait', 5),
#  ('flcrashcorrectors', 5),
#  ('htgawm', 5),
#  ('ressing', 5),
#  ('vscogood', 5),
#  ('glastofest', 5),
#  ('canadiangp', 5),
#  ('shopthemint', 5),
#  ('lained', 5),
#  ('youthday', 5),
#  ('wakow', 5),
#  ('lovewins', 5),
#  ('lokiday', 5),
#  ('paners', 5),
#  ('ramadankareem', 5),
#  ('crookedhillary', 5),
#  ('stockboy', 5),
#  ('selfserving', 5),
#  ('selacted', 5),
#  ('blaxican', 5),
#  ('trumptrain', 5),
#  ('dumptrump', 5),
#  ('jocoxmp', 5),
#  ('officebearers', 5),
#  ('sukhbir', 5),
#  ('dementeddonny', 5),
#  ('ression', 5),
#  ('writerslife', 5),
#  ('jeepmafia', 4),
#  ('birthdaykazuki', 4),
#  ('gokaldas', 4),
#  ('oitnbchat', 4),
#  ('aldub', 4),
#  ('kharkivgram', 4),
#  ('suppoed', 4),
#  ('bigly', 4),
#  ('eureferendum', 4),
#  ('stephcurrys', 4),
#  ('tedatibm', 4),
#  ('zionazis', 4),
#  ('diracting', 4),
#  ('bigender', 4),
#  ('prayorlando', 4),
#  ('mogage', 4),
#  ('actorslife', 4),
#  ('brokenquotes', 4),
#  ('trumpuniversity', 4),
#  ('ripantonyelchin', 4),
#  ('lopezchiro', 4),
#  ('unchaed', 4),
#  ('unpresidented', 4),
#  ('apaheid', 4),
#  ('laining', 4),
#  ('fianc', 4),
#  ('bdayspl', 4),
#  ('vscoturkey', 4),
#  ('tubbytoons', 4),
#  ('bestfriendsday', 4),
#  ('injuns', 4),
#  ('orienting', 4),
#  ('notmypres', 4),
#  ('huing', 4),
#  ('orlandostrong', 4),
#  ('drumpf', 4),
#  ('ojmadeinamerica', 4),
#  ('essentialoils', 4),
#  ('berniesanders', 4),
#  ('antiamerican', 4),
#  ('smaccdub', 4),
#  ('likeforlikealways', 4),
#  ('nuascannan', 4),
#  ('lapride', 4),
#  ('mohenjodaro', 4),
#  ('trumpsamerica', 4),
#  ('dreamproject', 4),
#  ('weareorlando', 4),
#  ('paladinos', 4),
#  ('democraticpay', 4),
#  ('ghettosdriven', 4),
#  ('shmurda', 4),
#  ('futureofwork', 4),
#  ('weddingpay', 4),
#  ('tshis', 4),
#  ('orlandolove', 4),
#  ('pharrellwilliams', 4),
#  ('shofilm', 4),
#  ('orlandohorror', 4),
#  ('irevswe', 4),
#  ('prayingfororlando', 4),
#  ('inwoo', 3),
#  ('growthhacking', 3),
#  ('annaswelshzoo', 3),
#  ('pittiuomo', 3),
#  ('udta', 3),
#  ('jeepnation', 3),
#  ('scoopwhoop', 3),
#  ('trumpworld', 3),
#  ('smaphone', 3),
#  ('audiblechannels', 3),
#  ('nifo', 3),
#  ('polosi', 3),
#  ('kikes', 3),
#  ('healess', 3),
#  ('makeamericagreatagain', 3),
#  ('stopgunviolence', 3),
#  ('teapay', 3),
#  ('socafrenzy', 3),
#  ('bluedress', 3),
#  ('morelove', 3),
#  ('womenempowerment', 3),
#  ('myhea', 3),
#  ('bodycleanse', 3),
#  ('oitnbseason', 3),
#  ('bihay', 3),
#  ('selfloathing', 3),
#  ('keshis', 3),
#  ('wouldictatorial', 3),
#  ('alkalamba', 3),
#  ('couesy', 3),
#  ('ectation', 3),
#  ('twtly', 3),
#  ('msqrd', 3),
#  ('kindleunlimited', 3),
#  ('whingers', 3),
#  ('feelthebern', 3),
#  ('frarou', 3),
#  ('theconjuring', 3),
#  ('nonracist', 3),
#  ('toyspotting', 3),
#  ('pokemonsunmoon', 3),
#  ('signofthetimes', 3),
#  ('bogotadc', 3),
#  ('gayvegas', 3),
#  ('wepretty', 3),
#  ('webad', 3),
#  ('annefrank', 3),
#  ('rapflashback', 3),
#  ('musicaltheatre', 3),
#  ('bluehand', 3),
#  ('eriment', 3),
#  ('girlsholiday', 3),
#  ('gahbrooks', 3),
#  ('familytrip', 3),
#  ('healthandfitness', 3),
#  ('akrotiri', 3),
#  ('knossos', 3),
#  ('capitalstb', 3),
#  ('loiting', 3),
#  ('boycottdelta', 3),
#  ('homeon', 3),
#  ('hackneywick', 3),
#  ('rebelhea', 3),
#  ('atbat', 3),
#  ('reelacted', 3),
#  ('hoosierstate', 3),
#  ('instaselfie', 3),
#  ('gotmelike', 3),
#  ('sex,', 3),
#  ('age,', 3),
#  ('bekindtooneanother', 3),
#  ('vscolove', 3),
#  ('instatagslikes', 3),
#  ('artices', 3),
#  ('switcharoo', 3),
#  ('mohammedali', 3),
#  ('smilemore', 3),
#  ('alicrytrinkets', 3),
#  ('enjoyinglife', 3),
#  ('xboxones', 3),
#  ('waspi', 3),
#  ('starawards', 3),
#  ('iampossible', 3),
#  ('momtips', 3),
#  ('fashionillustration', 3),
#  ('putinspuppet', 3),
#  ('putinschoice', 3),
#  ('jungkookday', 3),
#  ('mummersparade', 3),
#  ('nohampton', 3),
#  ('highlycontested', 3),
#  ('gettingfitter', 3),
#  ('colbe', 3),
#  ('oneplus', 3),
#  ('rickastley', 3),
#  ('girlno', 3),
#  ('infofuny', 3),
#  ('voteleave', 3),
#  ('poussey', 3),
#  ('amodu', 3),
#  ('gratata', 3),
#  ('golinuntern', 3),
#  ('indvszim', 3),
#  ('theduchessofcambridge', 3),
#  ('aldubthweeksary', 3),
#  ('enforcem', 3),
#  ('celebspot', 3),
#  ('sinkthepink', 3),
#  ('kylielipkit', 3),
#  ('kickstar', 3),
#  ('venusexchange', 3),
#  ('teamshide', 3),
#  ('shideism', 3),
#  ('thewi', 3),
#  ('patriotwatch', 3),
#  ('floridashooting', 3),
#  ('newbooks', 3),
#  ('eoeparceria', 3),
#  ('two-hump', 3),
#  ('birthdayyourmajesty', 3),
#  ('impsessions', 3),
#  ('newadventure', 3),
#  ('worldginday', 3),
#  ('diracted', 3),
#  ('mcbob', 3),
#  ('snapchater', 3),
#  ('abasel', 3),
#  ('yezidi', 3),
#  ('queenat', 3),
#  ('masterkeye', 3),
#  ('rondarousey', 3),
#  ('adamsaleh', 3),
#  ('doplants', 3),
#  ('pueorico', 3),
#  ('cursedchild', 3),
#  ('instatraveling', 3),
#  ('staups', 3),
#  ('summerfair', 3),
#  ('blackheathstandard', 3),
#  ('engwal', 3),
#  ('totellthetruth', 3),
#  ('augustth', 3),
#  ('streeta', 3),
#  ('bobross', 3),
#  ('downloadfestival', 3),
#  ('zootopia', 3),
#  ('bluelivesmatter', 3),
#  ('nintendoe', 3),
#  ('sundayvibes', 3),
#  ('makeuplover', 3),
#  ('followusoninstagram', 3),
#  ('stylehausboutique', 3),
#  ('albea', 3),
#  ('anglosaxon', 3),
#  ('infacted', 3),
#  ('lgbtqhatestrumppay', 3),
#  ('spoy', 3),
#  ('pueobanus', 3),
#  ('europeangp', 3),
#  ('katiequeue', 3),
#  ('alltypespos', 3),
#  ('islamicinfo', 3),
#  ('gamesofthrones', 3),
#  ('curbyourenthusiasm', 3),
#  ('bookstagram', 3),
#  ('alohafriday', 3),
#  ('menner', 3),
#  ('harambe', 3),
#  ('copaamerica', 3),
#  ('lnicjustanevilbday', 3),
#  ('lnic', 3),
#  ('ahfodtour', 3),
#  ('fotokuapp', 3),
#  ('maialas', 3),
#  ('aggressions', 3),
#  ('blogtacular', 3),
#  ('oscarpretorious', 3),
#  ('freshsta', 3),
#  ('drugaddicts', 3),
#  ('kimorablac', 3),
#  ('yrkkh', 3),
#  ('draintheswamp', 3),
#  ('nattaway', 2),
#  ('kadesh', 2),
#  ('usatt', 2),
#  ('unreformable', 2),
#  ('melges', 2),
#  ('foitude', 2),
#  ('ethnocentrism', 2),
#  ('doublesided', 2),
#  ('naoyuki', 2),
#  ('newplace', 2),
#  ('qcbags', 2),
#  ('hickstead', 2),
#  ('ilovegin', 2),
#  ('chaani', 2),
#  ('zionazi', 2),
#  ('cinemahall', 2),
#  ('thweeksary', 2),
#  ('birthdayjodistamaria', 2),
#  ('ngitingtagumpay', 2),
#  ('nationalroseday', 2),
#  ('chatbot', 2),
#  ('yahoomessenger', 2),
#  ('senseaboutmaths', 2),
#  ('adahzeh', 2),
#  ('biserjamess', 2),
#  ('buckinghampalace', 2),
#  ('aneveningwithcyrus', 2),
#  ('teletubbiesusa', 2),
#  ('ontheredcarpet', 2),
#  ('argvbol', 2),
#  ('justicereform', 2),
#  ('nrocks', 2),
#  ('voez', 2),
#  ('sitgesanytime', 2),
#  ('envatomarket', 2),
#  ('birstall', 2),
#  ('milleniawalk', 2),
#  ('skyback', 2),
#  ('oculusrift', 2),
#  ('summershowers', 2),
#  ('findhappiness', 2),
#  ('almostweekend', 2),
#  ('hepwoh', 2),
#  ('amaniknew', 2),
#  ('paxex', 2),
#  ('unitednations', 2),
#  ('houseofolive', 2),
#  ('rajkuamar', 2),
#  ('bodyscrubs', 2),
#  ('scrab', 2),
#  ('wheredobrokenheasgo', 2),
#  ('wheredoibelong', 2),
#  ('womenvote', 2),
#  ('abrahamhicks', 2),
#  ('heatherfitzpatrick', 2),
#  ('bestpeople', 2),
#  ('thankyoustudio', 2),
#  ('goreing', 2),
#  ('sunworld', 2),
#  ('lstv', 2),
#  ('toomanyemorions', 2),
#  ('didthatreallyjusthappen', 2),
#  ('readytopay', 2),
#  ('birthdaytreat', 2),
#  ('datemyfamily', 2),
#  ('squadgoals', 2),
#  ('greatacting', 2),
#  ('emptynest', 2),
#  ('lutsen', 2),
#  ('fridayfunday', 2),
#  ('businessopportunity', 2),
#  ('itwing', 2),
#  ('greendays', 2),
#  ('mckechnie', 2),
#  ('socialhistory', 2),
#  ('noheast', 2),
#  ('sffs', 2),
#  ('disseation', 2),
#  ('nationalfreelancersday', 2),
#  ('beyourownboss', 2),
#  ('dogfriends', 2),
#  ('jeepgirl', 2),
#  ('cssday', 2),
#  ('nuure', 2),
#  ('votetrumpsave', 2),
#  ('yogalife', 2),
#  ('theodyssey', 2),
#  ('magnettherapy', 2),
#  ('memoriesmatter', 2),
#  ('simonstone', 2),
#  ('desdelaraiz', 2),
#  ('castingcall', 2),
#  ('pileupriddim', 2),
#  ('sweetpeart', 2),
#  ('jewelmaze', 2),
#  ('louismainjr', 2),
#  ('ripanton', 2),
#  ('fisherprice', 2),
#  ('swanlake', 2),
#  ('lanation', 2),
#  ('fireflymusicfestival', 2),
#  ('soundtrainingnews', 2),
#  ('hindalco', 2),
#  ('panono', 2),
#  ('positivevibesonly', 2),
#  ('noheels', 2),
#  ('babylife', 2),
#  ('bragadayjah', 2),
#  ('ahntrio', 2),
#  ('thoughtswithorlando', 2),
#  ('teamcatmojo', 2),
#  ('sugardaddies', 2),
#  ('ccblooms', 2),
#  ('brewpix', 2),
#  ('laurasworld', 2),
#  ('iamchoosinglove', 2),
#  ('realbeauty', 2),
#  ('junesuitejune', 2),
#  ('stinkyclothes', 2),
#  ('shoking', 2),
#  ('weakdonald', 2),
#  ('spssv', 2),
#  ('spfx', 2),
#  ('adidasler', 2),
#  ('alwaystrump', 2),
#  ('youmakemesmile', 2),
#  ('gdegblog', 2),
#  ('diepsloot', 2),
#  ('authenticself', 2),
#  ('nohcarolina', 2),
#  ('greatsinger', 2),
#  ('bekindtoanimals', 2),
#  ('bekindalways', 2),
#  ('rexit', 2),
#  ('mealprep', 2),
#  ('bobovr', 2),
#  ('beautifulworld', 2),
#  ('selfrealization', 2),
#  ('gmschurch', 2),
#  ('lowenergy', 2),
#  ('spinellis', 2),
#  ('tminushours', 2),
#  ('xians', 2),
#  ('jaguarfpace', 2),
#  ('jaguarstb', 2),
#  ('fpace', 2),
#  ('findoutnow', 2),
#  ('lovecornwall', 2),
#  ('ponsanooth', 2),
#  ('wsib', 2),
#  ('studyni', 2),
#  ('ihbelfast', 2),
#  ('sitgesgaypride', 2),
#  ('thoughtleaders', 2),
#  ('weinerdog', 2),
#  ('angloamerican', 2),
#  ('itaxnirahisi', 2),
#  ('yeezyboost', 2),
#  ('instahappyday', 2),
#  ('hhmatters', 2),
#  ('lainable', 2),
#  ('pulsefitness', 2),
#  ('illrun', 2),
#  ('traumaticbraininjury', 2),
#  ('unasolagozadera', 2),
#  ('thestoneroses', 2),
#  ('growthwithhubspot', 2),
#  ('holymonth', 2),
#  ('goauche', 2),
#  ('eriaz', 2),
#  ('postapocalyptic', 2),
#  ('humpdaymotivation', 2),
#  ('stillwithher', 2),
#  ('notbetterweather', 2),
#  ('selfinterest', 2),
#  ('homehouse', 2),
#  ('kindledeals', 2),
#  ('aldubthmonthsary', 2),
#  ('balless', 2),
#  ('sheprollygonnadocrack', 2),
#  ('bjmuzic', 2),
#  ('bjmckenzie', 2),
#  ('reignofkong', 2),
#  ('moodoftheday', 2),
#  ('bernieorbust', 2),
#  ('gooddyeyoung', 2),
#  ('syrianrefugees', 2),
#  ('rationchallenge', 2),
#  ('upcm', 2),
#  ('myphotography', 2),
#  ('spiritualjourney', 2),
#  ('ripjulimuffn', 2),
#  ('oldpainting', 2),
#  ('jenniferaniston', 2),
#  ('smilepowerday', 2),
#  ('bremain', 2),
#  ('doodlerindelhi', 2),
#  ('shoage', 2),
#  ('nofail', 2),
#  ('bhagmojobhag', 2),
#  ('owlashop', 2),
#  ('emtec', 2),
#  ('traitorump', 2),
#  ('carryhappiness', 2),
#  ('hellolulu', 2),
#  ('comprehpensive', 2),
#  ('junaricrm', 2),
#  ('wcvbpoli', 2),
#  ('uyanze', 2),
#  ('luube', 2),
#  ('gettingreal', 2),
#  ('udtapunjabtoflytomorrow', 2),
#  ('chimpo', 2),
#  ('lowiq', 2),
#  ('queenelizabeths', 2),
#  ('ladylouisewindsor', 2),
#  ('invisibleillness', 2),
#  ('tuckercarlson', 2),
#  ('mumlife', 2),
#  ('ihearadio', 2),
#  ('volunteersweek', 2),
#  ('bmottphoto', 2),
#  ('yogalove', 2),
#  ('lifetips', 2),
#  ('resso', 2),
#  ('flyswiss', 2),
#  ('aftenro', 2),
#  ('popularvote', 2),
#  ('newflat', 2),
#  ('elixer', 2),
#  ('doughdiscoday', 2),
#  ('teamhawthorn', 2),
#  ('radiolife', 2),
#  ('hillbots', 2),
#  ('preprogrammed', 2),
#  ('joepalacios', 2),
#  ('friendshipneverends', 2),
#  ('felizdiadelpadre', 2),
#  ('yosoytupadre', 2),
#  ('hogwas', 2),
#  ('weddingtime', 2),
#  ('bynight', 2),
#  ('openwaterswimming', 2),
#  ('climatecrimes', 2),
#  ('antiracist', 2),
#  ('kongebloggen', 2),
#  ('comicpalooza', 2),
#  ('hereticfoundation', 2),
#  ('powerhungrytraitors', 2),
#  ('parsonsxteenvogue', 2),
#  ('troopingthecolour', 2),
#  ('sosassy', 2),
#  ('galwayhour', 2),
#  ('barryjayhughes', 2),
#  ('ceificate', 2),
#  ('ladyzaradurose', 2),
#  ('jadhav', 2),
#  ('inktober', 2),
#  ('damoor', 2),
#  ('bravebu', 2),
#  ('mrssa', 2),
#  ('twtl', 2),
#  ('subgenres', 2),
#  ('studentnurse', 2),
#  ('pmpm', 2),
#  ('besteduonline', 2),
#  ('whitenationalist', 2),
#  ('descendantsofthesun', 2),
#  ('howbeautifultour', 2),
#  ('ottawaigers', 2),
#  ('summerisbetter', 2),
#  ('jonsnow', 2),
#  ('rejacting', 2),
#  ('farewellrexallplace', 2),
#  ('summerk', 2),
#  ('amjoy', 2),
#  ('theyorkshirespirit', 2),
#  ('danieldash', 2),
#  ('dominicanblogger', 2),
#  ('usedbytrump', 2),
#  ('antaica', 2),
#  ('gorgeousgirl', 2),
#  ('tinfoilhat', 2),
#  ('sequinbow', 2),
#  ('thinskinned', 2),
#  ('ludacriss', 2),
#  ('verbalassault', 2),
#  ('goodvibesonly', 2),
#  ('hulkmode', 2),
#  ('lukehemmings', 2),
#  ('livelifetothefullest', 2),
#  ('prechula', 2),
#  ('miniwd', 2),
#  ('tehaleh', 2),
#  ('holmium', 2),
#  ('vsupercars', 2),
#  ('amensia', 2),
#  ('crashbandicoot', 2),
#  ('stockphoto', 2),
#  ('helthy', 2),
#  ('liveinthemoment', 2),
#  ('queerly', 2),
#  ('curriculumday', 2),
#  ('dailysketch', 2),
#  ('jarretts', 2),
#  ('followanyway', 2),
#  ('islamicterrorism', 2),
#  ('happycampers', 2),
#  ('socialanxiety', 2),
#  ('narnfraud', 2),
#  ('magnetize', 2),
#  ('parkhouse', 2),
#  ('cloudlovers', 2),
#  ('heroesdayug', 2),
#  ('firsthome', 2),
#  ('waterspos', 2),
#  ('farright', 2),
#  ('campadams', 2),
#  ('nothese', 2),
#  ('kazzeymusic', 2),
#  ('dinavalenz', 2),
#  ('biggestever', 2),
#  ('tanamsendiri', 2),
#  ('harummanis', 2),
#  ('wahabism', 2),
#  ('cloudchaser', 2),
#  ('senselessviolence', 2),
#  ('scesdshines', 2),
#  ('rickity', 2),
#  ('colourmehappy', 2),
#  ('letstalkabout', 2),
#  ('wankpuffins', 2),
#  ('cuailing', 2),
#  ('beautifulcityhostel', 2),
#  ('economicapahied', 2),
#  ('notpencil', 2),
#  ('winsorandnewton', 2),
#  ('fabercastell', 2),
#  ('canievenpaintanymore', 2),
#  ('baender', 2),
#  ('toddington', 2),
#  ('sunseasand', 2),
#  ('charmars', 2),
#  ('ineedtoconsult', 2),
#  ('collacted', 2),
#  ('mozlondon', 2),
#  ('canaryislands', 2),
#  ('pahlajnihalani', 2),
#  ('beloy', 2),
#  ('themorningfix', 2),
#  ('pohcawlbikehire', 2),
#  ('blogginggals', 2),
#  ('wodeh', 2),
#  ('indignenous', 2),
#  ('cushite', 2),
#  ('richardspencer', 2),
#  ('insidethebelljar', 2),
#  ('engvrus', 2),
#  ('riskoff', 2),
#  ('jimrohn', 2),
#  ('haggerstoncastlewiththefam', 2),
#  ('twoshot', 2),
#  ('herballife', 2),
#  ('plantbased', 2),
#  ('tokifuji', 2),
#  ('thedayproject', 2),
#  ('lulybtips', 2),
#  ('spreadhappiness', 2),
#  ('stephenkeshi', 2),
#  ('anmolshare', 2),
#  ('armaanamaalontkss', 2),
#  ('lovebts', 2),
#  ('thiy', 2),
#  ('americafirst', 2),
#  ('selfdevelopment', 2),
#  ('affirmativeaction', 2),
#  ('newadventures', 2),
#  ('singlemother', 2),
#  ('supposmallstreams', 2),
#  ('naturelovers', 2),
#  ('yuge', 2),
#  ('mysistersgraduation', 2),
#  ('macgrad', 2),
#  ('someonecomewithme', 2),
#  ('samanthabee', 2),
#  ('hohum', 2),
#  ('hotvideo', 2),
#  ('bankerhits', 2),
#  ('unceain', 2),
#  ('upliftingnews', 2),
#  ('hfhradio', 2),
#  ('yehtut', 2),
#  ('goromania', 2),
#  ('brokenhea', 2),
#  ('conflates', 2),
#  ('trumplies', 2),
#  ('appleta', 2),
#  ('mansoon', 2),
#  ('steaknight', 2),
#  ('dadanddaughter', 2),
#  ('goaded', 2),
#  ('egsmile', 2),
#  ('runvi', 2),
#  ('urbacity', 2),
#  ('corroborated', 2),
#  ('lifestyleblogger', 2),
#  ('ubie', 2),
#  ('bringabankstatementandwecantalk', 2),
#  ('canihelpyou', 2),
#  ('everydaybeautiful', 2),
#  ('toureiffel', 2),
#  ('timhoons', 2),
#  ('bearlovestravel', 2),
#  ('riclswtravelbook', 2),
#  ('reathie', 2),
#  ('helloe', 2),
#  ('behello', 2),
#  ('lovereading', 2),
#  ('stoni', 2),
#  ('woodrowwilson', 2),
#  ('glastonburyfestival', 2),
#  ('fowoh', 2),
#  ('trumpusa', 2),
#  ('mateens', 2),
#  ('australiangold', 2),
#  ('blacksea', 2),
#  ('paulgeorge', 2),
#  ('onebigfamily', 2),
#  ('bloggersblast', 2),
#  ('fahersday', 2),
#  ('eahquake', 2),
#  ('germay', 2),
#  ('salonaks', 2),
#  ('reflacted', 2),
#  ('dumbdonalddestroying', 2),
#  ('ivankatrump', 2),
#  ('takuyakimura', 2),
#  ('waitingf', 2),
#  ('nodream', 2),
#  ('globalwellnessday', 2),
#  ('bankett', 2),
#  ('vintagestyle', 2),
#  ('illmissyouguys', 2),
#  ('gratefuleveryday', 2),
#  ('ilitary', 2),
#  ('watchm', 2),
#  ('weekendfun', 2),
#  ('cricker', 2),
#  ('weddingcountdown', 2),
#  ('traveltheworld', 2),
#  ('kushite', 2),
#  ('ohodontic', 2),
#  ('whererefreshingbegins', 2),
#  ('ckkosho', 2),
#  ('dadsrock', 2),
#  ('growthmindset', 2),
#  ('casfactor', 2),
#  ('tosoon', 2),
#  ('dailycatimpression', 2),
#  ('frankfu', 2),
#  ('bouncesoff', 2),
#  ('dinneime', 2),
#  ('lanations', 2),
#  ('justmarried', 2),
#  ('liveslost', 2),
#  ('kickstarcampaign', 2),
#  ('funimate', 2),
#  ('hikingadventures', 2),
#  ('fathersdayweekend', 2),
#  ('antisemites', 2),
#  ('neverhillary', 2),
#  ('bossbabe', 2),
#  ('boxcup', 2),
#  ('halfassed', 2),
#  ('phillysuppophilly', 2),
#  ('mlpseason', 2),
#  ('dwpwishlist', 2),
#  ('redacts', 2),
#  ('girlgamer', 2),
#  ('personesilenziose', 2),
#  ('albumdenyansiyanlar', 2),
#  ('bloggercake', 2),
#  ('ypttl', 2),
#  ('boricuasmile', 2),
#  ('wordword', 2),
#  ('prayforoakland', 2),
#  ('gordiehowe', 2),
#  ('touga', 2),
#  ('doublewin', 2),
#  ('savesask', 2),
#  ('liveahappysexylife', 2),
#  ('myfirsttweet', 2),
#  ('loyalcustomer', 2),
#  ('trinationodi', 2),
#  ('indraloka', 2),
#  ('birthdaysurprise', 2),
#  ('liveallyourdreams', 2),
#  ('josephjett', 2),
#  ('greatloss', 2),
#  ('ushistory', 2),
#  ('affacting', 2),
#  ('effacted', 2),
#  ('froontin', 2),
#  ('europegp', 2),
#  ('racewar', 2),
#  ('attorneygeneral', 2),
#  ('mummybloggers', 2),
#  ('goldenstatewarriors', 2),
#  ('johnyblazed', 2),
#  ('terrorattack', 2),
#  ('wefie', 2),
#  ('burakyeter', 2),
#  ('lipolight', 2),
#  ('maidsafe', 2),
#  ('femikuti', 2),
#  ('ariellesloth', 2),
#  ('racemix', 2),
#  ('teamhants', 2),
#  ('aleers', 2),
#  ('interrailing', 2),
#  ('greatweek', 2),
#  ('smilingbutimclosetotears', 2),
#  ('breitba', 2),
#  ('digitalnomad', 2),
#  ('mygarden', 2),
#  ('herbalremedies', 2),
#  ('lorer', 2),
#  ('travelwoman', 2),
#  ('focusonyourself', 2),
#  ('publiceducation', 2),
#  ('motherood', 2),
#  ('likefollow', 2),
#  ('kingcarlgustaf', 2),
#  ('queensilvia', 2),
#  ('riprick', 2),
#  ('projacting', 2),
#  ('wohwhile', 2),
#  ('africanamericans', 2),
#  ('prayforchristina', 2),
#  ('thenanny', 2),
#  ('mdcollege', 2),
#  ('soulightmovement', 2),
#  ('nationalday', 2),
#  ('princessestelle', 2),
#  ('notlongtogo', 2),
#  ('planch', 2),
#  ('thegamefair', 2),
#  ('albanpilgrimage', 2),
#  ('keyair', 2),
#  ('losion', 2),
#  ('thursdaytreat', 2),
#  ('nationaleggday', 2),
#  ('ejacted', 2),
#  ('pulsenightclubshooting', 2),
#  ('hatefilled', 2),
#  ('dhugga', 2),
#  ('caridge', 2),
#  ('ripgrimmie', 2),
#  ('letthegamebefair', 2),
#  ('jaredgifthread', 2),
#  ('depressededit', 2),
#  ('ukpubs', 2),
#  ('lovepubs', 2),
#  ('proslavery', 2),
#  ('nhsscot', 2),
#  ('freedomconference', 2),
#  ('friendshipgoals', 2),
#  ('shohairdontcare', 2),
#  ('gofoen', 2),
#  ('youthpreprofessional', 2),
#  ('debutnovel', 2),
#  ('theaofmurder', 2),
#  ('firsttimeauthor', 2),
#  ('realtorgirl', 2),
#  ('ebht', 2),
#  ('newsta', 2),
#  ('standwithorlando', 2),
#  ('headisease', 2),
#  ('aboion', 2),
#  ('rogueone', 2),
#  ('trumpgeorge', 2),
#  ('mofknz', 2),
#  ('pikegs', 2),
#  ('rapeugee', 2),
#  ('taharrushgamea', 2),
#  ('taharrush', 2),
#  ('nomorehate', 2),
#  ('mommyduties', 2),
#  ('heavenoneah', 2),
#  ('wypipo', 2),
#  ('fabdivas', 2),
#  ('wrongdecision', 2),
#  ('picoftheevening', 2),
#  ('dahvader', 2),
#  ('religiouspsychosis', 2),
#  ('forher', 2),
#  ('dogwalking', 2),
#  ('goodfeelings', 2),
#  ('healand', 2),
#  ('shuaibu', 2),
#  ('thursdaymotivation', 2),
#  ('moulinyan', 2),
#  ('udthapunjab', 2),
#  ('characterdesign', 2),
#  ('ballsruns', 2),
#  ('abglp', 2),
#  ('windturbines', 2),
#  ('costest', 2),
#  ('happiestk', 2),
#  ('airingofthegrievances', 2),
#  ('feelingpretty', 2),
#  ('botnek', 2),
#  ('antiislam', 2),
#  ('losions', 2),
#  ('strictlyto', 2),
#  ('charactermatters', 2),
#  ('chroniclescontinues', 2),
#  ('hottweets', 2),
#  ('stockmusic', 2),
#  ('royaltyfreemusic', 2),
#  ('fridaythoughts', 2),
#  ('salutethefather', 2),
#  ('areacodemixshow', 2),
#  ('ripojb', 2),
#  ('djhumility', 2),
#  ...]

# %%
for pat, repl in spellings.items():
    train.tweet = train.tweet.str.replace(pat, repl)
    test.tweet = test.tweet.str.replace(pat,repl)

# %%
train["tweet"][2]
# Out:
# '<user> protestors rally to support teen facing life sentence in pot brownie case really stupid not for a brownie'

# %%
vocab = build_vocab(list(test['tweet'].apply(lambda x:x.split())))
#vocab
oov = check_coverage(vocab,glove_embed)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=11949.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=18818.0), HTML(value='')))
# Found embeddings for 80.53% of vocab
# Found embeddings for  97.72% of all text

# %%
oov
# Out:
# [('allahsoil', 26),
#  ('brexit', 24),
#  ('prayfororlando', 16),
#  ('simple,', 16),
#  ('orlandoshooting', 14),
#  ('ripchristina', 12),
#  ('melancholymusic', 12),
#  ('udtapunjab', 9),
#  ('spos', 9),
#  ('teambts', 8),
#  ('staup', 7),
#  ('offpensive', 7),
#  ('christinagrimmie', 7),
#  ('theconjuring', 7),
#  ('ripchristinagrimmie', 7),
#  ('treetz', 7),
#  ('amodu', 6),
#  ('inshot', 6),
#  ('ceain', 6),
#  ('paner', 6),
#  ('shuaibu', 5),
#  ('elsmads', 5),
#  ('orlandohorror', 5),
#  ('altright', 5),
#  ('yelchin', 5),
#  ('bouncingbaby', 5),
#  ('porait', 5),
#  ('bogumday', 4),
#  ('vlicobs', 4),
#  ('woyke', 4),
#  ('flagday', 4),
#  ('prayersfororlando', 4),
#  ('carlpaladino', 4),
#  ('uselections', 4),
#  ('glastofest', 4),
#  ('altwaystoheal', 4),
#  ('prayforchristina', 4),
#  ('actorslife', 4),
#  ('brokenhea', 4),
#  ('teamsuperjunior', 4),
#  ('queenat', 4),
#  ('albea', 4),
#  ('antonyelchin', 4),
#  ('sundaymood', 3),
#  ('kharkivgram', 3),
#  ('barrybonds', 3),
#  ('corracted', 3),
#  ('pulseshooting', 3),
#  ('uggaa', 3),
#  ('mmusimaimane', 3),
#  ('naitik', 3),
#  ('giphy', 3),
#  ('lldhoodruiner', 3),
#  ('bihay', 3),
#  ('smilemore', 3),
#  ('anhangover', 3),
#  ('royaltyfreemusic', 3),
#  ('nowlinkup', 3),
#  ('ladykimora', 3),
#  ('shopalyssas', 3),
#  ('repoing', 3),
#  ('aists', 3),
#  ('paytime', 3),
#  ('shopthemint', 3),
#  ('ukhx', 3),
#  ('treasonoustrump', 3),
#  ('apaheid', 3),
#  ('staups', 3),
#  ('shiless', 3),
#  ('raghuramrajan', 3),
#  ('weddinganniversary', 3),
#  ('fotokuapp', 3),
#  ('vscogood', 3),
#  ('vscoph', 3),
#  ('schwandorfchwandorf', 3),
#  ('thinkbigsundaywithmarsha', 3),
#  ('troyal', 3),
#  ('feelthebern', 3),
#  ('lutsen', 3),
#  ('orlandonightclubshooting', 3),
#  ('capitalstb', 3),
#  ('jocox', 3),
#  ('kabali', 3),
#  ('momtips', 3),
#  ('puntohost', 3),
#  ('myhermes', 2),
#  ('makeupaddict', 2),
#  ('pizzaslice', 2),
#  ('freshsta', 2),
#  ('balanceldn', 2),
#  ('gravitypoisoning', 2),
#  ('ginzos', 2),
#  ('sososad', 2),
#  ('careerconvos', 2),
#  ('greathonour', 2),
#  ('udta', 2),
#  ('holibra', 2),
#  ('superfabric', 2),
#  ('prayingfororlando', 2),
#  ('bearlovestravel', 2),
#  ('riclswtravelbook', 2),
#  ('losions', 2),
#  ('riribarbie', 2),
#  ('shideism', 2),
#  ('teamshide', 2),
#  ('pamelaramseytaylor', 2),
#  ('lovebts', 2),
#  ('ojmadeinamerica', 2),
#  ('lphop', 2),
#  ('miscegenation', 2),
#  ('niggadoe', 2),
#  ('nycranshaw', 2),
#  ('soplayer', 2),
#  ('theshield', 2),
#  ('eeti', 2),
#  ('joytrain', 2),
#  ('catsoftwitter', 2),
#  ('mgaenp', 2),
#  ('pllseason', 2),
#  ('suarezs', 2),
#  ('bopanna', 2),
#  ('thehistorypic', 2),
#  ('pokemongo', 2),
#  ('nationallobsterday', 2),
#  ('slimmingworldusa', 2),
#  ('pleasedontrain', 2),
#  ('aboutitnigga', 2),
#  ('impsessions', 2),
#  ('stockmusic', 2),
#  ('kinlopes', 2),
#  ('suffolkhour', 2),
#  ('usofa', 2),
#  ('folkmusic', 2),
#  ('ppoppo', 2),
#  ('fucktrump', 2),
#  ('ohorsemen', 2),
#  ('diysos', 2),
#  ('shmoney', 2),
#  ('smilepowerday', 2),
#  ('berniebros', 2),
#  ('blowoutsbringhappiness', 2),
#  ('daddybeto', 2),
#  ('ondom', 2),
#  ('chefdemos', 2),
#  ('monsoonpunemarket', 2),
#  ('ressjs', 2),
#  ('ruifier', 2),
#  ('lovegold', 2),
#  ('bossmum', 2),
#  ('bossbabe', 2),
#  ('aldubthmonthsary', 2),
#  ('vegasqueens', 2),
#  ('rejacted', 2),
#  ('balakrishna', 2),
#  ('propey', 2),
#  ('chaysin', 2),
#  ('bohochic', 2),
#  ('lyversfacts', 2),
#  ('thelyvers', 2),
#  ('xvu', 2),
#  ('greatwhite', 2),
#  ('trumpusa', 2),
#  ('vuhsace', 2),
#  ('birthdaytome', 2),
#  ('jocoxmp', 2),
#  ('excitede', 2),
#  ('presidentobama', 2),
#  ('aelmunturo', 2),
#  ('napbacks', 2),
#  ('butthu', 2),
#  ('beinlife', 2),
#  ('sweetpeart', 2),
#  ('ethnocentrism', 2),
#  ('jaguarfpace', 2),
#  ('jaguarstb', 2),
#  ('fpace', 2),
#  ('pharrellwilliams', 2),
#  ('connacted', 2),
#  ('lighttherapy', 2),
#  ('funnehanever', 2),
#  ('vscodaily', 2),
#  ('millionmiler', 2),
#  ('plantbutler', 2),
#  ('engrus', 2),
#  ('ufcottawa', 2),
#  ('keshis', 2),
#  ('travelingram', 2),
#  ('htgawm', 2),
#  ('growthhacking', 2),
#  ('berniesanders', 2),
#  ('pittiuomo', 2),
#  ('breitba', 2),
#  ('artices', 2),
#  ('bremain', 2),
#  ('dogsoftwitter', 2),
#  ('weddingwednesday', 2),
#  ('weektogo', 2),
#  ('essentialoils', 2),
#  ('orangeisthenewblack', 2),
#  ('overwatch', 2),
#  ('xians', 2),
#  ('lains', 2),
#  ('odriguez', 2),
#  ('ournewbridge', 2),
#  ('officefails', 2),
#  ('coldplaywembley', 2),
#  ('socialaction', 2),
#  ('aupairlife', 2),
#  ('familyfunnight', 2),
#  ('deanambrose', 2),
#  ('wwewaco', 2),
#  ('neighbourgoods', 2),
#  ('onference', 2),
#  ('tupperwear', 2),
#  ('christmasadve', 2),
#  ('internationalsushiday', 2),
#  ('clothesshow', 2),
#  ('companymusicvideo', 2),
#  ('oitnbseason', 2),
#  ('glamsquad', 2),
#  ('boatclub', 2),
#  ('connacting', 2),
#  ('rainnyday', 2),
#  ('betterlife', 2),
#  ('orlandounited', 2),
#  ('seeyouinthefields', 2),
#  ('destinyriseofiron', 2),
#  ('hotgamesandroid', 2),
#  ('basedbuddhadev', 2),
#  ('minyoongi', 2),
#  ('bangtanboys', 2),
#  ('orienting', 2),
#  ('floridashooting', 2),
#  ('cowardcops', 2),
#  ('officerstaff', 2),
#  ('camstaff', 2),
#  ('cameronstaff', 2),
#  ('eadle', 2),
#  ('mothereah', 2),
#  ('loveisland', 2),
#  ('uponeaglewings', 2),
#  ('eahathon', 2),
#  ('zosh', 2),
#  ('adidasrunning', 2),
#  ('whiteknight', 2),
#  ('cavsnation', 2),
#  ('notsleep', 2),
#  ('povey', 2),
#  ('comprehpensive', 2),
#  ('lordwillin', 2),
#  ('anziel', 2),
#  ('warcraftmovie', 2),
#  ('starek', 2),
#  ('wifehappylife', 2),
#  ('sneakershow', 2),
#  ('birthdayjohnnydepp', 2),
#  ('fathersdayquotes', 2),
#  ('hoosierdaddy', 2),
#  ('cedm', 2),
#  ('otdad', 1),
#  ('doplants', 1),
#  ('kokcoutureclothing', 1),
#  ('beedaboss', 1),
#  ('goaldigger', 1),
#  ('msme', 1),
#  ('yfmghana', 1),
#  ('statueoflibel', 1),
#  ('antiherorocks', 1),
#  ('needstwitter', 1),
#  ('wxctyx', 1),
#  ('genuinescooters', 1),
#  ('smileday', 1),
#  ('pwwf', 1),
#  ('meckis', 1),
#  ('bemeckis', 1),
#  ('pornobike', 1),
#  ('newbike', 1),
#  ('zipperheads', 1),
#  ('keshun', 1),
#  ('goodvibesonly', 1),
#  ('bdayweekend', 1),
#  ('ppmkpi', 1),
#  ('kpcqio', 1),
#  ('stumppass', 1),
#  ('lovefl', 1),
#  ('teamlh', 1),
#  ('canadiangp', 1),
#  ('panamahat', 1),
#  ('withfriends', 1),
#  ('daystogokianandjc', 1),
#  ('officialmbmusic', 1),
#  ('mixedbabies', 1),
#  ('babytalk', 1),
#  ('afrane', 1),
#  ('disciplinarian', 1),
#  ('lovehasntwonyet', 1),
#  ('justicereform', 1),
#  ('feelsorryforme', 1),
#  ('somuchfunlasttime', 1),
#  ('pixiecut', 1),
#  ('pahoja', 1),
#  ('damians', 1),
#  ('rockfuck', 1),
#  ('newsghana', 1),
#  ('netanyahou', 1),
#  ('blendedfamily', 1),
#  ('stormsocial', 1),
#  ('tbstorm', 1),
#  ('aforsale', 1),
#  ('abstractpainting', 1),
#  ('outoforder', 1),
#  ('mesenchymal', 1),
#  ('fightms', 1),
#  ('atorfamily', 1),
#  ('oaker', 1),
#  ('kylielipkit', 1),
#  ('kyliecosmetics', 1),
#  ('lipkit', 1),
#  ('firstnighttonight', 1),
#  ('czwqy', 1),
#  ('dwig', 1),
#  ('defpensive', 1),
#  ('deemef', 1),
#  ('redskind', 1),
#  ('nsme', 1),
#  ('snetteon', 1),
#  ('replicastuk', 1),
#  ('atysyc', 1),
#  ('blogginggals', 1),
#  ('tnekvtp', 1),
#  ('umbrelas', 1),
#  ('blagoevgrad', 1),
#  ('cakeryboutiquemx', 1),
#  ('cakerymx', 1),
#  ('ghazals', 1),
#  ('lovepoetry', 1),
#  ('sunisshining', 1),
#  ('ditw', 1),
#  ('londonjameszurich', 1),
#  ('dasischz', 1),
#  ('opernhaus', 1),
#  ('rogueone', 1),
#  ('esign', 1),
#  ('uidesign', 1),
#  ('diracted', 1),
#  ('zji', 1),
#  ('qzqs', 1),
#  ('tltro', 1),
#  ('illuminatebyashley', 1),
#  ('rapeyass', 1),
#  ('stevenuniverse', 1),
#  ('xvus', 1),
#  ('uminati', 1),
#  ('bgwg', 1),
#  ('junebabies', 1),
#  ('vzhqc', 1),
#  ('chicagomeditation', 1),
#  ('chicagovloggers', 1),
#  ('untgoblins', 1),
#  ('americanninjawarrior', 1),
#  ('pullz', 1),
#  ('traverwood', 1),
#  ('imisswinter', 1),
#  ('gotjoy', 1),
#  ('scramblin', 1),
#  ('studentlyfisgold', 1),
#  ('sesalefueeadele', 1),
#  ('fatherz', 1),
#  ('congroutz', 1),
#  ('kueulangtahun', 1),
#  ('kuekering', 1),
#  ('kuelebaran', 1),
#  ('nofriendsnolife', 1),
#  ('lifemember', 1),
#  ('sangeeth', 1),
#  ('bellkiller', 1),
#  ('murderedsoulsuspect', 1),
#  ('myanmars', 1),
#  ('itcouldvebeenme', 1),
#  ('wishiwasbetter', 1),
#  ('carele', 1),
#  ('nastybaby', 1),
#  ('dericious', 1),
#  ('souffl', 1),
#  ('pacchos', 1),
#  ('chuckers', 1),
#  ('aiculate', 1),
#  ('xzg', 1),
#  ('poorservice', 1),
#  ('afterchurch', 1),
#  ('hotelma', 1),
#  ('paners', 1),
#  ('ahahhskavsa', 1),
#  ('cashual', 1),
#  ('sheisinallsecretagamer', 1),
#  ('cyclades', 1),
#  ('lagosmarehotel', 1),
#  ('febch', 1),
#  ('pastrychefs', 1),
#  ('patissiere', 1),
#  ('allthingsnew', 1),
#  ('sundaymorningride', 1),
#  ('vodpass', 1),
#  ('pkffgn', 1),
#  ('kimorablac', 1),
#  ('justwannatalk', 1),
#  ('feelingignored', 1),
#  ('notnamingnames', 1),
#  ('weddinginspiration', 1),
#  ('cambtweet', 1),
#  ('vyaiu', 1),
#  ('illist', 1),
#  ('soomanday', 1),
#  ('laining', 1),
#  ('gatogordo', 1),
#  ('rqn', 1),
#  ('jviw', 1),
#  ('newclassmates', 1),
#  ('gunlaws', 1),
#  ('lastmonthbeing', 1),
#  ('likethisone', 1),
#  ('fridaynightsinlondon', 1),
#  ('isdtc', 1),
#  ('toddsquad', 1),
#  ('ontothefinals', 1),
#  ('junaricrm', 1),
#  ('nomoresnapchat', 1),
#  ('moresad', 1),
#  ('andultra', 1),
#  ('bustymilf', 1),
#  ('diyaly', 1),
#  ('lightspeedgirls', 1),
#  ('xtremeairk', 1),
#  ('forestpark', 1),
#  ('suicidesquad', 1),
#  ('peacein', 1),
#  ('ummii', 1),
#  ('hvzyn', 1),
#  ('ollusions', 1),
#  ('ollusion', 1),
#  ('ngvyxrw', 1),
#  ('tunnelview', 1),
#  ('weareorlando', 1),
#  ('bringonliverpoolstbeers', 1),
#  ('okrah', 1),
#  ('whoolo', 1),
#  ('royalorchid', 1),
#  ('geoffreys', 1),
#  ('chaclacayo', 1),
#  ('afroperuvian', 1),
#  ('syberianhusky', 1),
#  ('conservapocalypse', 1),
#  ('democraticpay', 1),
#  ('bariviarules', 1),
#  ('newbusiness', 1),
#  ('selenatorsfamily', 1),
#  ('silverspring', 1),
#  ('choosinh', 1),
#  ('tiafoe', 1),
#  ('weekendupdate', 1),
#  ('rainyseason', 1),
#  ('mumbaimonsoon', 1),
#  ('daddysays', 1),
#  ('misogny', 1),
#  ('imfragile', 1),
#  ('mysonshine', 1),
#  ('genusultra', 1),
#  ('ronf', 1),
#  ('letiziah', 1),
#  ('spamblocked', 1),
#  ('paralleled', 1),
#  ('niesr', 1),
#  ('ilsleepwhenimdead', 1),
#  ('slingshotwake', 1),
#  ('wakesurfing', 1),
#  ('titlus', 1),
#  ('doublewin', 1),
#  ('ibelieveinbitcoin', 1),
#  ('bitfinex', 1),
#  ('furiousonpix', 1),
#  ('hillaryclintons', 1),
#  ('newdirection', 1),
#  ('pleaselike', 1),
#  ('xmaqt', 1),
#  ('gaywrites', 1),
#  ('lbum', 1),
#  ('appface', 1),
#  ('teamdope', 1),
#  ('shitler', 1),
#  ('enddogfighting', 1),
#  ('steveking', 1),
#  ('redsea', 1),
#  ('bestvacations', 1),
#  ('runmalawi', 1),
#  ('latinmusic', 1),
#  ('itsalive', 1),
#  ('funandgames', 1),
#  ('steampunkarmor', 1),
#  ('blueleds', 1),
#  ('aseprite', 1),
#  ('pixela', 1),
#  ('larrydavid', 1),
#  ('curbyourenthusiasm', 1),
#  ('alandra', 1),
#  ('strayhorn', 1),
#  ('morningsex', 1),
#  ('depressionquotes', 1),
#  ('depressedquotes', 1),
#  ('michaeljace', 1),
#  ('dogwalking', 1),
#  ('feelssoreal', 1),
#  ('sexymundie', 1),
#  ('suspacted', 1),
#  ('twtly', 1),
#  ('iaccoca', 1),
#  ('dobhair', 1),
#  ('gaoth', 1),
#  ('deleteyouraaccount', 1),
#  ('wednesdaymorning', 1),
#  ('mqc', 1),
#  ('reathie', 1),
#  ('veryhard', 1),
#  ('xhexm', 1),
#  ('holidaycomingtoanend', 1),
#  ('lequaisttropez', 1),
#  ('sttropez', 1),
#  ('comeseeus', 1),
#  ('ilovenature', 1),
#  ('ilovecolorado', 1),
#  ('geniushowto', 1),
#  ('ejrbakker', 1),
#  ('moulie', 1),
#  ('viswa', 1),
#  ('\U000feb0e', 1),
#  ('agirllikeher', 1),
#  ('theriveourberlin', 1),
#  ('believeinyou', 1),
#  ('whywhiteworks', 1),
#  ('whiteaddict', 1),
#  ('handlettering', 1),
#  ('buandmaxs', 1),
#  ('biday', 1),
#  ('cottoncandynapmat', 1),
#  ('wednesdaymotivation', 1),
#  ('goodtimeswithgo', 1),
#  ('klokus', 1),
#  ('fgbsihhe', 1),
#  ('societytoday', 1),
#  ('maidofhonor', 1),
#  ('ripantonyelchin', 1),
#  ('youaresoverybadguy', 1),
#  ('yoelegicorrer', 1),
#  ('upandrunning', 1),
#  ('nightlifelocater', 1),
#  ('hunkie', 1),
#  ('buildbridgesnotwalls', 1),
#  ('loveandpeace', 1),
#  ('illypsycho', 1),
#  ('foamroll', 1),
#  ('weeksofexercise', 1),
#  ('truuooth', 1),
#  ('ufeellucky', 1),
#  ('wbruchal', 1),
#  ('blackmaverick', 1),
#  ('cptplanespotter', 1),
#  ('phantomaviation', 1),
#  ('starfightersaturday', 1),
#  ('mrrat', 1),
#  ('unbreakablekimmyschmidt', 1),
#  ('byyrr', 1),
#  ('deplayeo', 1),
#  ('youtotallylied', 1),
#  ('reedzy', 1),
#  ('bigmagic', 1),
#  ('misinform', 1),
#  ('topexsound', 1),
#  ('deadliestplaceoneah', 1),
#  ('jfv', 1),
#  ('colourism', 1),
#  ('littlebuddy', 1),
#  ('travistip', 1),
#  ('qhvnwb', 1),
#  ('suppoed', 1),
#  ('sanx', 1),
#  ('korilakkuma', 1),
#  ('angelicpretty', 1),
#  ('sweetlolita', 1),
#  ('lolitafashion', 1),
#  ('gettingannoyed', 1),
#  ('benghazis', 1),
#  ('ilovehorses', 1),
#  ('sprucemeadows', 1),
#  ('namethefoal', 1),
#  ('crownclasp', 1),
#  ('malachiteclutch', 1),
#  ('pinked', 1),
#  ('longtimes', 1),
#  ('boronia', 1),
#  ('felixyosua', 1),
#  ('littlefamily', 1),
#  ('sheople', 1),
#  ('michaelcalfan', 1),
#  ('nobodydoesitbetter', 1),
#  ('ctue', 1),
#  ('niceplace', 1),
#  ('mainbushra', 1),
#  ('mereharjai', 1),
#  ('lamashtu', 1),
#  ('justroses', 1),
#  ('erhereicome', 1),
#  ('mandingos', 1),
#  ('islamicterrorist', 1),
#  ('jwcyu', 1),
#  ('stillcantbeliveyoudidthis', 1),
#  ('myminecraftrobot', 1),
#  ('brokenquotes', 1),
#  ('vlxu', 1),
#  ('alohafriday', 1),
#  ('coffecream', 1),
#  ('qquit', 1),
#  ('abstractaist', 1),
#  ('feelingbad', 1),
#  ('talentlab', 1),
#  ('thursdaytreat', 1),
#  ('birthdayameeshapatel', 1),
#  ('admint', 1),
#  ('panamapacifico', 1),
#  ('pacificolifecentre', 1),
#  ('englishtutoring', 1),
#  ('upjqq', 1),
#  ('bestbeaches', 1),
#  ('newsmyrnabeach', 1),
#  ('bikinibabe', 1),
#  ('isqf', 1),
#  ('blacksupremacist', 1),
#  ('itveuref', 1),
#  ('loadupp', 1),
#  ('ateme', 1),
#  ('dontendkahanihamari', 1),
#  ('cockerspanielsofinstagram', 1),
#  ('aniversarioinfantil', 1),
#  ('sverigesweden', 1),
#  ('phonicsounds', 1),
#  ('whitefragility', 1),
#  ('bougainvilliea', 1),
#  ('couroom', 1),
#  ('celebspot', 1),
#  ('sinkthepink', 1),
#  ('happinesswins', 1),
#  ('excotic', 1),
#  ('mangara', 1),
#  ('endhate', 1),
#  ('hearingallhersong', 1),
#  ('crycraft', 1),
#  ('spongethursday', 1),
#  ('reelacted', 1),
#  ('mexicanfashionblogger', 1),
#  ('bogummy', 1),
#  ('xtatic', 1),
#  ('prchat', 1),
#  ('staylocal', 1),
#  ('xci', 1),
#  ('onlyattheducksgame', 1),
#  ('busterposey', 1),
#  ('newblood', 1),
#  ('newcastleemlyn', 1),
#  ('foodfestival', 1),
#  ('freeballout', 1),
#  ('nohpark', 1),
#  ('acnease', 1),
#  ('yearofmercy', 1),
#  ('hopetojoinyou', 1),
#  ('regestration', 1),
#  ('thehuntingpay', 1),
#  ('evidenceusa', 1),
#  ('belatedbirthday', 1),
#  ('knowyourboundaries', 1),
#  ('joblove', 1),
#  ('teambadassofanarchy', 1),
#  ('soalegend', 1),
#  ('enjjwm', 1),
#  ('dreamfantasyland', 1),
#  ('abndp', 1),
#  ('whiteperson', 1),
#  ('dpil', 1),
#  ('freethenipple', 1),
#  ('dhei', 1),
#  ('gullu', 1),
#  ('thejourneybegins', 1),
#  ('karrenchi', 1),
#  ('unbiosibs', 1),
#  ('dreamreso', 1),
#  ('drewm', 1),
#  ('beensqueezing', 1),
#  ('nigor', 1),
#  ('perfectlyposh', 1),
#  ('davidlloyd', 1),
#  ('onnell', 1),
#  ('fuckhashtags', 1),
#  ('youready', 1),
#  ('joshuabreazeale', 1),
#  ('onwednesdayswewearpink', 1),
#  ('ripchri', 1),
#  ('teamgrimmie', 1),
#  ('zwujc', 1),
#  ('congressmans', 1),
#  ('thomasjefferson', 1),
#  ('ramsaybolton', 1),
#  ('mdsat', 1),
#  ('sonicthehedgehog', 1),
#  ('bosay', 1),
#  ('crowddoctor', 1),
#  ('vibrantskinvibrantlife', 1),
#  ('whitesboro', 1),
#  ('atrapaba', 1),
#  ('zyf', 1),
#  ('aend', 1),
#  ('keszwl', 1),
#  ('bkza', 1),
#  ('ryx', 1),
#  ('dontsettle', 1),
#  ('chaneesays', 1),
#  ('sdodson', 1),
#  ('americanfootball', 1),
#  ('symones', 1),
#  ('lovecas', 1),
#  ('finaldesternation', 1),
#  ('worldwarzpatwo', 1),
#  ('filmby', 1),
#  ('youoksis', 1),
#  ('unsuspacting', 1),
#  ('arianagrandedrawing', 1),
#  ('parisattack', 1),
#  ('aspiremag', 1),
#  ('thewestin', 1),
#  ('hefoundnemo', 1),
#  ('doesntlikethesharks', 1),
#  ('lovesthefish', 1),
#  ('upsta', 1),
#  ('reinventimpossible', 1),
#  ('osean', 1),
#  ('rightous', 1),
#  ('huing', 1),
#  ('qrdbm', 1),
#  ('bigboat', 1),
#  ('fhsparis', 1),
#  ('spermicidal', 1),
#  ('ekizz', 1),
#  ('spoime', 1),
#  ('unprotacted', 1),
#  ('ohodox', 1),
#  ('collacted', 1),
#  ('sleepday', 1),
#  ('sundayvibes', 1),
#  ('thankfulforwhatsapp', 1),
#  ('velicaria', 1),
#  ('nooneforgetsthetruth', 1),
#  ('salmahayek', 1),
#  ('burntpizza', 1),
#  ('watdidijustsee', 1),
#  ('anded', 1),
#  ('savecharity', 1),
#  ('ackiechan', 1),
#  ('goodsunday', 1),
#  ('markantalya', 1),
#  ('peshmerga', 1),
#  ('duckeggblue', 1),
#  ('bumoose', 1),
#  ('littleenglander', 1),
#  ('confoable', 1),
#  ('ursexiestmorena', 1),
#  ('lackchick', 1),
#  ('princesscookieneckbackcrack', 1),
#  ('furfamily', 1),
#  ('teamfluffnevabluff', 1),
#  ('goodnightforreal', 1),
#  ('summerfair', 1),
#  ('blackheathstandard', 1),
#  ('riseofiron', 1),
#  ('theflash', 1),
#  ('dogblog', 1),
#  ('chowchows', 1),
#  ('chowcow', 1),
#  ('magictm', 1),
#  ('radiogoa', 1),
#  ('konkani', 1),
#  ('webcammodel', 1),
#  ('saheliapparels', 1),
#  ('blackjune', 1),
#  ('nohumberland', 1),
#  ('ihopeitssuposetobetonight', 1),
#  ('nlydirtymike', 1),
#  ('eurogi', 1),
#  ('showeek', 1),
#  ('completefuckup', 1),
#  ('twbr', 1),
#  ('holdingon', 1),
#  ('zovik', 1),
#  ('mackinacisland', 1),
#  ('heavenoneah', 1),
#  ('projectdrugs', 1),
#  ('loveudisha', 1),
#  ('ishqbaaz', 1),
#  ('dishu', 1),
#  ('phedhrs', 1),
#  ('fairuse', 1),
#  ('racheltatum', 1),
#  ('snapcht', 1),
#  ('islamicterror', 1),
#  ('legalgun', 1),
#  ('whiteguy', 1),
#  ('innin', 1),
#  ('eogiro', 1),
#  ('ripgop', 1),
#  ('wouldolphins', 1),
#  ('redditchbizhour', 1),
#  ('stayourlife', 1),
#  ('nutritionalrebalancing', 1),
#  ('djks', 1),
#  ('weslayin', 1),
#  ('babykroixontheway', 1),
#  ('saviles', 1),
#  ('donrik', 1),
#  ('uncomfutable', 1),
#  ('raghead', 1),
#  ('zfgjp', 1),
#  ('onlywantonenight', 1),
#  ('jayballout', 1),
#  ('teapay', 1),
#  ('jaipurdiaries', 1),
#  ('fpnruku', 1),
#  ('wellybel', 1),
#  ('gojaysgo', 1),
#  ('endoftheline', 1),
#  ('battleofthebastards', 1),
#  ('mudmask', 1),
#  ('celeblife', 1),
#  ('imawaytobesick', 1),
#  ('peaceday', 1),
#  ('killthelightstour', 1),
#  ('deathbattle', 1),
#  ('kyrielebron', 1),
#  ('collacting', 1),
#  ('orlandosho', 1),
#  ('bharjari', 1),
#  ('sweetbabins', 1),
#  ('highgang', 1),
#  ('teamspade', 1),
#  ('biiaatch', 1),
#  ('hatchys', 1),
#  ('noques', 1),
#  ('cooldad', 1),
#  ('ectallweathers', 1),
#  ('upthebum', 1),
#  ('mugtheduck', 1),
#  ('nzg', 1),
#  ('qbfw', 1),
#  ('ancake', 1),
#  ('asuivre', 1),
#  ('sharkette', 1),
#  ('smcr', 1),
#  ('ceegee', 1),
#  ('peacefestival', 1),
#  ('oneyearofhinaontwiteer', 1),
#  ('ledwell', 1),
#  ('hcota', 1),
#  ('tbuomzy', 1),
#  ('perfectbedday', 1),
#  ('weneedit', 1),
#  ('pouringrain', 1),
#  ('remainineu', 1),
#  ('pastrycheflife', 1),
#  ('reasymonkey', 1),
#  ('iwantgameofthrones', 1),
#  ('quetarojas', 1),
#  ('qrmodelos', 1),
#  ('mamatothreeboys', 1),
#  ('odindavid', 1),
#  ('ebhour', 1),
#  ('rahals', 1),
#  ('billgetsbuns', 1),
#  ('vinnysnotmadon', 1),
#  ('fuckdimmy', 1),
#  ('xingmi', 1),
#  ('selfhate', 1),
#  ('begoodtoyourself', 1),
#  ('lemonwater', 1),
#  ('kanecrookes', 1),
#  ('jyubqr', 1),
#  ('dirz', 1),
#  ('womenempowerment', 1),
#  ('upcm', 1),
#  ('fwher', 1),
#  ('upsideofflorida', 1),
#  ('talenttalk', 1),
#  ('stankiest', 1),
#  ('skirossendale', 1),
#  ('dvhsskitrip', 1),
#  ('droided', 1),
#  ('thehoboco', 1),
#  ('\U000fe7d6', 1),
#  ('alldoctor', 1),
#  ('blessedandgrateful', 1),
#  ('niieeggaa', 1),
#  ('ilovedrawing', 1),
#  ('redsmoke', 1),
#  ('hoonicorn', 1),
#  ('slurr', 1),
#  ('fridayfaves', 1),
#  ('ginfilled', 1),
#  ('mutualrespect', 1),
#  ('pvnjk', 1),
#  ('xeq', 1),
#  ('drafte', 1),
#  ('oopsbuzz', 1),
#  ('adeolu', 1),
#  ('blaske', 1),
#  ('fjf', 1),
#  ('engwal', 1),
#  ('rashford', 1),
#  ('yellowlabs', 1),
#  ('\U000feb96', 1),
#  ('weekendsmiles', 1),
#  ('xyrm', 1),
#  ('yakked', 1),
#  ('felonsplease', 1),
#  ('ibrary', 1),
#  ('ilostmyhat', 1),
#  ('fruitsnack', 1),
#  ('corz', 1),
#  ('isleofwight', 1),
#  ('tuningout', 1),
#  ('listflawed', 1),
#  ('winterfashion', 1),
#  ('davenpo', 1),
#  ('walrustalks', 1),
#  ('americafirst', 1),
#  ('quallcom', 1),
#  ('scoc', 1),
#  ('daystoolong', 1),
#  ('weremissinghim', 1),
#  ('consultantlife', 1),
#  ('phdlife', 1),
#  ('phdstudent', 1),
#  ('potusisourdividerinchief', 1),
#  ('tooyoungtodie', 1),
#  ('ourleadersaresleeping', 1),
#  ('thirstdays', 1),
#  ('birthdayrg', 1),
#  ('ryukomatoi', 1),
#  ('rutba', 1),
#  ('birdsmovie', 1),
#  ('foaleza', 1),
#  ('picofthenight', 1),
#  ('mrfzwj', 1),
#  ('afection', 1),
#  ('ferkin', 1),
#  ('towlerlindsay', 1),
#  ('prayerchangesthings', 1),
#  ('poion', 1),
#  ('kidsset', 1),
#  ('kharkivcity', 1),
#  ('crazycats', 1),
#  ('uenez', 1),
#  ('lukehemmings', 1),
#  ('flawging', 1),
#  ('weavetrip', 1),
#  ('pulsenightclubshooting', 1),
#  ('pherell', 1),
#  ('hwawards', 1),
#  ('yourhea', 1),
#  ('beverlywhaling', 1),
#  ('americadoesntwantyou', 1),
#  ('lostpopularvote', 1),
#  ('whydoitry', 1),
#  ('woodsford', 1),
#  ('ahfod', 1),
#  ('menner', 1),
#  ('blessedmonday', 1),
#  ('pdit', 1),
#  ('murrayhaters', 1),
#  ('gdvp', 1),
#  ('pwctalentacademy', 1),
#  ('pleasestaydry', 1),
#  ('prayfoheworld', 1),
#  ('hbgary', 1),
#  ('sockpuppetarmy', 1),
#  ('dceaglecam', 1),
#  ('reellifers', 1),
#  ('hellytweets', 1),
#  ('hellyshah', 1),
#  ('eyetalian', 1),
#  ('rapechucktodd', 1),
#  ('bitcoiners', 1),
#  ('vscoa', 1),
#  ('vscoapp', 1),
#  ('arcusc', 1),
#  ('yesiamstillsalty', 1),
#  ('oveime', 1),
#  ('robzombie', 1),
#  ...]

# %% [markdown]
# ## These include hashtags

# %%
train.to_csv("../dataset/GLOVE_TRAIN#")

# %%
test.to_csv("../dataset/GLOVE_TEST#")

# %%
pd.read_csv("../dataset/GLOVE_TEST#")["tweet"][1]
# Out:
# '<user> lots of <hashtag> resistance and <hashtag> challenges from some of my favorite <hashtag> thoughtleaders <hashtag> mentors it is not just you'

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42509 entries, 0 to 42508
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  42509 non-null  int64
#  1   tweet       42509 non-null  object
#  2   class       42509 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 996.4+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11949 entries, 0 to 11948
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  11949 non-null  int64
#  1   tweet       11949 non-null  object
#  2   class       11949 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 280.2+ KB

# %% [markdown]
# ## These do not include hashtags

# %%
vocab = build_vocab(list(pd.read_csv("../dataset/GLOVE_TRAIN")['tweet'].apply(lambda x:x.split())))
#vocab
oov = check_coverage(vocab,glove_embed)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=42364.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=26956.0), HTML(value='')))
# Found embeddings for 89.29% of vocab
# Found embeddings for  99.42% of all text

# %%
vocab = build_vocab(list(pd.read_csv("../dataset/GLOVE_TEST")['tweet'].apply(lambda x:x.split())))
#vocab
oov = check_coverage(vocab,glove_embed)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=11949.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=13608.0), HTML(value='')))
# Found embeddings for 93.05% of vocab
# Found embeddings for  99.37% of all text

# %% [markdown]
# # Tokenisation

# %%
ef load_embedding(file, tokenizer):
    def split(line):
        word, *arr = line.split(' ')
        return word, np.asarray(arr, dtype='float32')
    with open(file, encoding='utf8', errors='ignore') as f:
        if DEBUG:
            embeddings = dict(split(line) for line in tqdm(itertools.islice(f, 10000)) if len(line) > 100)
        else:
            embeddings = dict(split(line) for line in tqdm(f) if len(line) > 100)
    values = np.stack(embeddings.values())
    mean = values.mean()
    std = values.std()
    n_words = min(MAX_FEATURES, len(tokenizer.word_index))
    
    embedding_matrix = np.random.normal(mean, std, (n_words, EMBED_SIZE))
    for word, i in tokenizer.word_index.items():
        if i < MAX_FEATURES and word in embeddings:
            embedding_matrix[i] = embeddings[word]
            
    return embedding_matrix

# %%
# %r{"(?i)\b((?:https?:(?:/{1,3}|[a-z0-9%])|[a-z0-9.\-]+[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)/)(?:[^\s()<>{}\[\]]+|\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\))+(?:\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’])|(?:(?<!@)[a-z0-9]+(?:[.\-][a-z0-9]+)*[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)\b/?(?!@)))"}
# Out:
# UsageError: Line magic function `%r{"(?i)\b((?:https?:(?:/{1,3}|[a-z0-9%])|[a-z0-9.\-]+[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)/)(?:[^\s()<>{}\[\]]+|\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\))+(?:\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’])|(?:(?<!@)[a-z0-9]+(?:[.\-][a-z0-9]+)*[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)\b/?(?!@)))"}` not found.
